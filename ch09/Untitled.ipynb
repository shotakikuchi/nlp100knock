# %% [markdown]
# # 第9章: RNN, CNN

# %% [markdown]
# ## 80. ID番号への変換
# 問題51で構築した学習データ中の単語にユニークなID番号を付与したい．
# 学習データ中で最も頻出する単語に1，2番目に頻出する単語に2，……といった方法で，学習データ中で2回以上出現する単語にID番号を付与せよ．
# そして，与えられた単語列に対して，ID番号の列を返す関数を実装せよ．
# ただし，出現頻度が2回未満の単語のID番号はすべて0とせよ．

# %%
import pandas as pd
import os
import joblib
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

# %%
data_dir = '../ch06'

# %%
X_train = pd.read_table(os.path.join(data_dir,'train.txt'), header=None)
X_test = pd.read_table(os.path.join(data_dir,'test.txt'), header=None)
X_valid = pd.read_table(os.path.join(data_dir,'valid.txt'), header=None)

cols = ['TITLE', 'CATEGORY']
for data in [X_train, X_test, X_valid]:
    data.columns = cols

X_train['LABEL'] = 'train'
X_test['LABEL'] = 'test'
X_valid['LABEL'] = 'valid'

concat_df = pd.concat([X_train, X_test, X_valid]).reset_index(drop=True)
print(concat_df.shape)
CV = CountVectorizer(stop_words="english")
feature = CV.fit_transform(concat_df['TITLE'])
# Out:
# (13340, 3)

# %%
frequency = np.asarray(feature.toarray().sum(axis=0))

# %%
vocabulary_freq = {w:f for w,f in zip(CV.vocabulary_, frequency)}
vocabulary_freq = sorted(vocabulary_freq.items(), key=lambda x: -x[-1])
word2id = {vf[0]:i if vf[1] > 2 else 0  for i,vf in enumerate(vocabulary_freq)}

# %%
word2id
# Out:
# {'cubist': 0,
#  'shape': 1,
#  'ipcc': 2,
#  'dolorosa': 3,
#  'chases': 4,
#  'peacekeeping': 5,
#  'nuri': 6,
#  'wither': 7,
#  'buyouts': 8,
#  '16k': 9,
#  'korean': 10,
#  'starbucks': 11,
#  'prompt': 12,
#  'spot': 13,
#  'added': 14,
#  'clinton': 15,
#  'raunchy': 16,
#  'relative': 17,
#  '14th': 18,
#  'seasons': 19,
#  'subsidiary': 20,
#  'preacher': 21,
#  'xl': 22,
#  'cipriani': 23,
#  'sow': 24,
#  'shire': 25,
#  'comeback': 26,
#  'detective': 27,
#  'kreme': 28,
#  'scheming': 29,
#  'thirds': 30,
#  'cfdas': 31,
#  'doctrine': 32,
#  'strategies': 33,
#  'partnering': 34,
#  'pilgrim': 35,
#  'virgin': 36,
#  'abating': 37,
#  'exemption': 38,
#  'join': 39,
#  'depresses': 40,
#  'barring': 41,
#  'vacation': 42,
#  'floppy': 43,
#  'arnett': 44,
#  'canon': 45,
#  'channel': 46,
#  'applauds': 47,
#  'true': 48,
#  'pot': 49,
#  'biodelivery': 50,
#  'engineering': 51,
#  'flooding': 52,
#  'joaquin': 53,
#  'mix': 54,
#  'corset': 55,
#  'exploring': 56,
#  '325': 57,
#  'alps': 58,
#  'swarovski': 59,
#  'eurobond': 60,
#  'illustrates': 61,
#  'encouraging': 62,
#  'turnaround': 63,
#  'example': 64,
#  'eligible': 65,
#  'resumed': 66,
#  'reasons': 67,
#  'tears': 68,
#  'combines': 69,
#  'glowers': 70,
#  'fortified': 71,
#  'yogawear': 72,
#  'overly': 73,
#  '19m': 74,
#  'tightwad': 75,
#  'brazilian': 76,
#  '490000': 77,
#  'equities': 78,
#  'brush': 79,
#  'shamed': 80,
#  'disclose': 81,
#  'consolidation': 82,
#  'runoff': 83,
#  'bug': 84,
#  'swedbank': 85,
#  'school': 86,
#  'manganiello': 87,
#  'reign': 88,
#  'reacting': 89,
#  'toyota': 90,
#  'morris': 91,
#  'chong': 92,
#  'alcoa': 93,
#  'brought': 94,
#  'pantera': 95,
#  'misstep': 96,
#  'large': 97,
#  'jessie': 98,
#  'drag': 99,
#  'catches': 100,
#  'worthless': 101,
#  'lse': 102,
#  'cartoon': 103,
#  'stitches': 104,
#  'changes': 105,
#  'oecd': 106,
#  'eu2': 107,
#  '9m': 108,
#  'mechanism': 109,
#  'andre': 110,
#  'nudge': 111,
#  'sun': 112,
#  'curtailing': 113,
#  'bloom': 114,
#  'gymnastics': 115,
#  'global': 116,
#  'abuse': 117,
#  'slur': 118,
#  'jeremiah': 119,
#  'performers': 120,
#  'otis': 121,
#  '142136': 122,
#  'element': 123,
#  'orphan': 124,
#  'envoy': 125,
#  'retires': 126,
#  'stockpiled': 127,
#  'tootsie': 128,
#  'missile': 129,
#  'letters': 130,
#  'hacked': 131,
#  'livestock': 132,
#  'said': 133,
#  '27': 134,
#  'flaws': 135,
#  'parade': 136,
#  'comfy': 137,
#  'lionel': 138,
#  'potato': 139,
#  'fast': 140,
#  'infected': 141,
#  'dis': 142,
#  'gauges': 143,
#  'delta': 144,
#  'pyongyang': 145,
#  'forcing': 146,
#  'lane': 147,
#  'unrelenting': 148,
#  'iraq': 149,
#  'niche': 150,
#  'fey': 151,
#  'revolted': 152,
#  'clones': 153,
#  'lashing': 154,
#  'seize': 155,
#  'lows': 156,
#  'arts': 157,
#  'undervalued': 158,
#  'rampage': 159,
#  'vatican': 160,
#  'smarts': 161,
#  'ism': 162,
#  'dances': 163,
#  'favour': 164,
#  'sweater': 165,
#  'dog': 166,
#  'foster': 167,
#  'lights': 168,
#  'sock': 169,
#  'suggest': 170,
#  'failed': 171,
#  '1399985295432': 172,
#  'stance': 173,
#  'heres': 174,
#  'relocations': 175,
#  'bana': 176,
#  'escape': 177,
#  'aerialists': 178,
#  'antics': 179,
#  'automobiles': 180,
#  'videogames': 181,
#  'royce': 182,
#  'responsible': 183,
#  'planning': 184,
#  'kardasian': 185,
#  'cleared': 186,
#  'adopts': 187,
#  '860': 188,
#  'chocolatier': 189,
#  'adulthood': 190,
#  'achieving': 191,
#  'swarmies': 192,
#  'cells': 193,
#  'nature': 194,
#  'depths': 195,
#  'kun': 196,
#  'ageless': 197,
#  'conditional': 198,
#  'boom': 199,
#  'ringling': 200,
#  'akb48': 201,
#  'wallach': 202,
#  'ergon': 203,
#  'southwest': 204,
#  'xstrata': 205,
#  'kinnear': 206,
#  'bbb': 207,
#  'napoleon': 208,
#  'dorfman': 209,
#  'tragic': 210,
#  'ebooks': 211,
#  'oozes': 212,
#  'equation': 213,
#  'flexibility': 214,
#  'surveys': 215,
#  'distant': 216,
#  'uninsured': 217,
#  'naomi': 218,
#  'reclaims': 219,
#  'knickerbocker': 220,
#  'grande': 221,
#  'citrus': 222,
#  'pboc': 223,
#  'pack': 224,
#  'commemoration': 225,
#  'covet': 226,
#  '300k': 227,
#  '210m': 228,
#  'sketching': 229,
#  'tier': 230,
#  'tactics': 231,
#  'plummeting': 232,
#  'refreshed': 233,
#  'storytelling': 234,
#  'criminals': 235,
#  'licence': 236,
#  'crotch': 237,
#  'kakao': 238,
#  'knighthood': 239,
#  'wolves': 240,
#  'baz': 241,
#  '10': 242,
#  'sydney': 243,
#  'synergies': 244,
#  'bigger': 245,
#  'pays': 246,
#  'márquez': 247,
#  'cooper': 248,
#  'hedison': 249,
#  'owners': 250,
#  'unemployed': 251,
#  'diagnose': 252,
#  'raped': 253,
#  'empowering': 254,
#  'elon': 255,
#  'raps': 256,
#  'protections': 257,
#  'similar': 258,
#  'detain': 259,
#  'clarifies': 260,
#  'sesh': 261,
#  'insights': 262,
#  'sauces': 263,
#  'hairstyle': 264,
#  'usc': 265,
#  'healthcare': 266,
#  'thailand': 267,
#  'killer': 268,
#  'actors': 269,
#  'fundamental': 270,
#  'microbes': 271,
#  'fortune': 272,
#  'hoaxes': 273,
#  'teenagers': 274,
#  'expectancy': 275,
#  'slingshot': 276,
#  'vogue': 277,
#  'recapture': 278,
#  'finale': 279,
#  'mounting': 280,
#  'academic': 281,
#  'claire': 282,
#  'klein': 283,
#  '820': 284,
#  'emmett': 285,
#  'choosing': 286,
#  'announces': 287,
#  'rocks': 288,
#  'neil': 289,
#  'shrine': 290,
#  'gliese': 291,
#  'heir': 292,
#  'helt': 293,
#  'kart': 294,
#  'category': 295,
#  'entertainmentwise': 296,
#  'sentence': 297,
#  'bionic': 298,
#  'cube': 299,
#  'fedex': 300,
#  'bar': 301,
#  'survive': 302,
#  'cream': 303,
#  'scorecard': 304,
#  'wows': 305,
#  'boulange': 306,
#  'eon': 307,
#  'immigration': 308,
#  'barcode': 309,
#  'federal': 310,
#  'enters': 311,
#  'rush': 312,
#  'fronts': 313,
#  'orphanage': 314,
#  'apparent': 315,
#  'built': 316,
#  'booed': 317,
#  'stem': 318,
#  'wins': 319,
#  'sure': 320,
#  'suggestions': 321,
#  'wsbtv': 322,
#  'dreamed': 323,
#  'prolongs': 324,
#  'blaming': 325,
#  'microbeads': 326,
#  'script': 327,
#  'inquiry': 328,
#  'cos': 329,
#  'brittany': 330,
#  'wildcat': 331,
#  'fukushima': 332,
#  'eurosceptic': 333,
#  'versions': 334,
#  'punished': 335,
#  'boosts': 336,
#  'interviews': 337,
#  'reweight': 338,
#  'amgen': 339,
#  'capability': 340,
#  'eurosail': 341,
#  'avastin': 342,
#  'outcome': 343,
#  'glorified': 344,
#  '42000': 345,
#  'iliad': 346,
#  'loud': 347,
#  'clown': 348,
#  'respectfully': 349,
#  'fought': 350,
#  'dorothy': 351,
#  'sterling': 352,
#  'rate': 353,
#  'fatigue': 354,
#  'emerging': 355,
#  'viability': 356,
#  'willow': 357,
#  'acroyoga': 358,
#  'wsb': 359,
#  'dealtalk': 360,
#  'performing': 361,
#  'feathered': 362,
#  'brutal': 363,
#  'calmer': 364,
#  'artpop': 365,
#  'packard': 366,
#  'shut': 367,
#  'glitz': 368,
#  'connections': 369,
#  'kurdish': 370,
#  'separatists': 371,
#  'diamond': 372,
#  'suggestion': 373,
#  'teasing': 374,
#  'markets': 375,
#  'mazda': 376,
#  'squeeze': 377,
#  'lineup': 378,
#  'cheeky': 379,
#  'nobel': 380,
#  'golf': 381,
#  'roker': 382,
#  'agricultural': 383,
#  'buzz': 384,
#  'prom': 385,
#  'turbotax': 386,
#  'lays': 387,
#  'rip': 388,
#  'booze': 389,
#  'shelter': 390,
#  'weave': 391,
#  'slate': 392,
#  'endo': 393,
#  'men': 394,
#  'prosecutors': 395,
#  'law': 396,
#  'benedict': 397,
#  'antibiotics': 398,
#  'transformers': 399,
#  'quickens': 400,
#  'ascending': 401,
#  'drinkers': 402,
#  '1399983366398': 403,
#  'professionals': 404,
#  'jesus': 405,
#  'impossibly': 406,
#  'steven': 407,
#  'promotions': 408,
#  'bum': 409,
#  'residential': 410,
#  'ravaged': 411,
#  '5bn': 412,
#  'plumes': 413,
#  'afrezza': 414,
#  'research': 415,
#  'decide': 416,
#  'vista': 417,
#  'warning': 418,
#  'variety': 419,
#  'peltz': 420,
#  'accusing': 421,
#  'lucasfilm': 422,
#  'resveratrol': 423,
#  'svelte': 424,
#  'nordegren': 425,
#  'syndicate': 426,
#  'yacht': 427,
#  'york': 428,
#  'hurt': 429,
#  'bubonic': 430,
#  'calm': 431,
#  'shakes': 432,
#  'harness': 433,
#  'trooper': 434,
#  'local': 435,
#  'acted': 436,
#  'johannes': 437,
#  'frontier': 438,
#  'cortana': 439,
#  'nymex': 440,
#  '500': 441,
#  'shield': 442,
#  'modern': 443,
#  'construction': 444,
#  'line': 445,
#  'lego': 446,
#  'instant': 447,
#  'joining': 448,
#  'playerâ': 449,
#  'reputation': 450,
#  'shocks': 451,
#  'optus': 452,
#  'ramp': 453,
#  'proceed': 454,
#  'podcast': 455,
#  'gowns': 456,
#  'polar': 457,
#  'battled': 458,
#  'glance': 459,
#  'mosley': 460,
#  'modest': 461,
#  'animated': 462,
#  'ihackers': 463,
#  'outstanding': 464,
#  'comedian': 465,
#  'kills': 466,
#  'dwts': 467,
#  'abs': 468,
#  'lacking': 469,
#  'bg': 470,
#  '650': 471,
#  'eatocracy': 472,
#  'demonstrations': 473,
#  'adorned': 474,
#  'trimming': 475,
#  'concealing': 476,
#  'finma': 477,
#  'valentino': 478,
#  'approved': 479,
#  'june': 480,
#  'regain': 481,
#  'tumors': 482,
#  'require': 483,
#  'opts': 484,
#  'telefonica': 485,
#  'spares': 486,
#  'woody': 487,
#  'alliances': 488,
#  'lenovo': 489,
#  'given': 490,
#  'errors': 491,
#  'bra': 492,
#  'lyrics': 493,
#  'island': 494,
#  'blushing': 495,
#  'deciding': 496,
#  'aiding': 497,
#  'machines': 498,
#  'rapid': 499,
#  'chai': 500,
#  'reiterate': 501,
#  'pizzolatto': 502,
#  'wally': 503,
#  'lip': 504,
#  'guns': 505,
#  'museum': 506,
#  'missing': 507,
#  'loss': 508,
#  'sharply': 509,
#  'trek': 510,
#  'rustic': 511,
#  'odds': 512,
#  'upfront': 513,
#  'duck': 514,
#  'dents': 515,
#  'aspen': 516,
#  'creators': 517,
#  '32': 518,
#  'egglesfield': 519,
#  'slew': 520,
#  'wives': 521,
#  'nazi': 522,
#  'renounce': 523,
#  'bumper': 524,
#  'recap': 525,
#  'police': 526,
#  'ferguson': 527,
#  'tampering': 528,
#  'leather': 529,
#  'exposure': 530,
#  'collection': 531,
#  'clothes': 532,
#  'stats': 533,
#  'reduced': 534,
#  'hawkins': 535,
#  'maybe': 536,
#  'auctions': 537,
#  'won6n': 538,
#  'absence': 539,
#  'formally': 540,
#  'publisher': 541,
#  'doting': 542,
#  'greets': 543,
#  'strokes': 544,
#  'snoop': 545,
#  'mp': 546,
#  'gathers': 547,
#  'systemic': 548,
#  'stevens': 549,
#  'cockpit': 550,
#  'pullman': 551,
#  'irresponsible': 552,
#  'clarence': 553,
#  'lohan': 554,
#  'fail': 555,
#  'suffered': 556,
#  'defensive': 557,
#  'unaware': 558,
#  'poison': 559,
#  'magenta': 560,
#  'halts': 561,
#  'ashamed': 562,
#  'majors': 563,
#  'blunted': 564,
#  'acidic': 565,
#  'corps': 566,
#  'sunpower': 567,
#  'moonlight': 568,
#  'polled': 569,
#  'hypocrisy': 570,
#  'dayanara': 571,
#  'blumenthal': 572,
#  'shanghai': 573,
#  'comments': 574,
#  'need': 575,
#  'metals': 576,
#  'cranks': 577,
#  'danske': 578,
#  'sajak': 579,
#  'anemic': 580,
#  'curve': 581,
#  'topshop': 582,
#  'recruit': 583,
#  'pristine': 584,
#  'jeep': 585,
#  'babysat': 586,
#  'tariffs': 587,
#  'dorkify': 588,
#  'ambassadors': 589,
#  'streamlines': 590,
#  '19th': 591,
#  'loeb': 592,
#  'degeneres': 593,
#  'roger': 594,
#  'saw': 595,
#  'register': 596,
#  'galaxy': 597,
#  'consume': 598,
#  'throws': 599,
#  'january': 600,
#  'account': 601,
#  'develops': 602,
#  'departs': 603,
#  'clotting': 604,
#  'swords': 605,
#  'charter': 606,
#  'predatory': 607,
#  'traveling': 608,
#  'daydreams': 609,
#  'horned': 610,
#  'ukrlandfarming': 611,
#  'guideline': 612,
#  'internal': 613,
#  'new': 614,
#  'crush': 615,
#  'rules': 616,
#  'strategy': 617,
#  'eve': 618,
#  'took': 619,
#  'sticker': 620,
#  'bearish': 621,
#  'viewers': 622,
#  'ankle': 623,
#  'hayden': 624,
#  'ripping': 625,
#  'posting': 626,
#  'videos': 627,
#  'mocked': 628,
#  'washing': 629,
#  'regret': 630,
#  'wider': 631,
#  'poultry': 632,
#  'portray': 633,
#  'unofficially': 634,
#  'viall': 635,
#  'dwayne': 636,
#  'hurry': 637,
#  'oilfield': 638,
#  'flowers': 639,
#  'applaud': 640,
#  'drifts': 641,
#  'slightly': 642,
#  'draghi': 643,
#  'harry': 644,
#  'iggy': 645,
#  'directors': 646,
#  'plunging': 647,
#  'finalists': 648,
#  'proved': 649,
#  'beloved': 650,
#  'gdp': 651,
#  '49': 652,
#  'shoes': 653,
#  'archaeologists': 654,
#  'usb': 655,
#  'beyonces': 656,
#  'nftyg': 657,
#  'features': 658,
#  'mozilla': 659,
#  'mickelson': 660,
#  'brass': 661,
#  'brushed': 662,
#  'encounter': 663,
#  'escalation': 664,
#  'misspells': 665,
#  'aluminum': 666,
#  'jermaine': 667,
#  '6m': 668,
#  'passover': 669,
#  'humble': 670,
#  'registration': 671,
#  'sling': 672,
#  'oil': 673,
#  'maryland': 674,
#  'leads': 675,
#  'traders': 676,
#  'strengthens': 677,
#  'drive': 678,
#  'frontman': 679,
#  'russian': 680,
#  'contained': 681,
#  'newark': 682,
#  '1900': 683,
#  'defiant': 684,
#  'er': 685,
#  'estate': 686,
#  'backed': 687,
#  'gears': 688,
#  'jeddah': 689,
#  'ceos': 690,
#  'bedded': 691,
#  'reaps': 692,
#  'lunch': 693,
#  'vanquish': 694,
#  'bizarre': 695,
#  'michigan': 696,
#  'jeans': 697,
#  'vw': 698,
#  'getty': 699,
#  'masterminds': 700,
#  'jose': 701,
#  'iranians': 702,
#  'periphery': 703,
#  'oracle': 704,
#  'hungarian': 705,
#  'trolls': 706,
#  'actos': 707,
#  'reviewers': 708,
#  'lovin': 709,
#  'diss': 710,
#  'entirely': 711,
#  'blackrock': 712,
#  'relaunch': 713,
#  'recovered': 714,
#  'erykah': 715,
#  'items': 716,
#  'richie': 717,
#  'sizing': 718,
#  'bestseller': 719,
#  'seething': 720,
#  'aficionados': 721,
#  'aubrey': 722,
#  'communication': 723,
#  'tolmach': 724,
#  'rats': 725,
#  'resting': 726,
#  'visit': 727,
#  'freedom': 728,
#  'great': 729,
#  'quarterly': 730,
#  'moment': 731,
#  'warm': 732,
#  'charged': 733,
#  'shift': 734,
#  'peg': 735,
#  'penguin': 736,
#  'bids': 737,
#  'chronology': 738,
#  'australians': 739,
#  'urinate': 740,
#  'controversial': 741,
#  'anymore': 742,
#  'cries': 743,
#  'average': 744,
#  'origins': 745,
#  'compensation': 746,
#  '20headlines': 747,
#  'violates': 748,
#  'bijou': 749,
#  'fever': 750,
#  'keenness': 751,
#  'reassures': 752,
#  '82': 753,
#  'reduces': 754,
#  'autopsy': 755,
#  'bee': 756,
#  'snarl': 757,
#  'flips': 758,
#  'nlrb': 759,
#  'hiding': 760,
#  '9000': 761,
#  'branding': 762,
#  'writers': 763,
#  'deny': 764,
#  'boobs': 765,
#  'awkwardness': 766,
#  'touring': 767,
#  'midlife': 768,
#  'finavera': 769,
#  'ousted': 770,
#  'failing': 771,
#  'smartphone': 772,
#  'statistics': 773,
#  'frequency': 774,
#  'feels': 775,
#  'floyd': 776,
#  'randall': 777,
#  'range': 778,
#  'protective': 779,
#  'falcone': 780,
#  'cam': 781,
#  'hint': 782,
#  'integrys': 783,
#  'bye': 784,
#  'croatian': 785,
#  'slovak': 786,
#  'deregulation': 787,
#  'dealerships': 788,
#  'fgic': 789,
#  'mandatory': 790,
#  'grease': 791,
#  'forties': 792,
#  'astounded': 793,
#  'entourage': 794,
#  'antioxidant': 795,
#  'keytar': 796,
#  'mh370s': 797,
#  'favreau': 798,
#  'currency': 799,
#  'olympian': 800,
#  'cup': 801,
#  'obamacare': 802,
#  'jimmy': 803,
#  'andi': 804,
#  'sohar': 805,
#  'repay': 806,
#  'nears': 807,
#  'posthumous': 808,
#  'gadi': 809,
#  'arthritic': 810,
#  'sebastian': 811,
#  'expressions': 812,
#  'nymphomaniac': 813,
#  'fixation': 814,
#  'capitalism': 815,
#  'nighter': 816,
#  'tones': 817,
#  'sharing': 818,
#  'irene': 819,
#  'resignation': 820,
#  'greening': 821,
#  'immigrants': 822,
#  'documenting': 823,
#  'dutch': 824,
#  'accuser': 825,
#  'diary': 826,
#  'middlebrow': 827,
#  'copy': 828,
#  'knight': 829,
#  'menopausal': 830,
#  'spendy': 831,
#  'classic': 832,
#  'scarce': 833,
#  'mogul': 834,
#  'morphin': 835,
#  '3q': 836,
#  'lambesis': 837,
#  'escalate': 838,
#  'grandmother': 839,
#  'lawsuit': 840,
#  'photo': 841,
#  'bus': 842,
#  'wing': 843,
#  'observatory': 844,
#  'schools': 845,
#  'concert': 846,
#  'suicide': 847,
#  'detect': 848,
#  'robotic': 849,
#  'shiny': 850,
#  'clarify': 851,
#  'therapists': 852,
#  'obtains': 853,
#  'vaginal': 854,
#  'neeson': 855,
#  '787s': 856,
#  'manoeuvrability': 857,
#  'wrenn': 858,
#  'esm': 859,
#  'homesman': 860,
#  'strengthening': 861,
#  'palin': 862,
#  'eliminating': 863,
#  'rockwood': 864,
#  'crossover': 865,
#  'marlboro': 866,
#  'cleanse': 867,
#  'toughest': 868,
#  'forgiving': 869,
#  'laptop': 870,
#  'elena': 871,
#  'dissatisfaction': 872,
#  'granted': 873,
#  '2064': 874,
#  'vortex': 875,
#  'selena': 876,
#  'q1': 877,
#  'fell': 878,
#  'nissan': 879,
#  'clear': 880,
#  'kramer': 881,
#  'stroman': 882,
#  'labeouf': 883,
#  'candid': 884,
#  'elton': 885,
#  'connelly': 886,
#  'capitalists': 887,
#  'later': 888,
#  '511528': 889,
#  'internet': 890,
#  'carey': 891,
#  'shortly': 892,
#  'sabrina': 893,
#  'laggardly': 894,
#  'dazeem': 895,
#  'distasteful': 896,
#  'frosty': 897,
#  'joker': 898,
#  'dewan': 899,
#  'nike': 900,
#  'alcon': 901,
#  'surrealist': 902,
#  'required': 903,
#  'freebies': 904,
#  'nightmarish': 905,
#  'northern': 906,
#  'numbers': 907,
#  'theaters': 908,
#  'simultaneously': 909,
#  'mixtapes': 910,
#  'colin': 911,
#  'ratio': 912,
#  'programmers': 913,
#  'persisting': 914,
#  'venue': 915,
#  'chariklo': 916,
#  'deceiving': 917,
#  'hangover': 918,
#  'carmakers': 919,
#  'pebble': 920,
#  'graphic': 921,
#  'macau': 922,
#  'mistakes': 923,
#  'intact': 924,
#  'pricey': 925,
#  '60000ft': 926,
#  'trackers': 927,
#  'titanosaur': 928,
#  'torres': 929,
#  'buck': 930,
#  'claims': 931,
#  'companies': 932,
#  'lags': 933,
#  'jolie': 934,
#  'ending': 935,
#  'givenchy': 936,
#  'tour': 937,
#  '911': 938,
#  'restore': 939,
#  'mila': 940,
#  'sells': 941,
#  'friend': 942,
#  'diaz': 943,
#  'earths': 944,
#  'shrink': 945,
#  'marietta': 946,
#  'choreographing': 947,
#  'salt': 948,
#  'plummeted': 949,
#  'www': 950,
#  '210716': 951,
#  'ordinary': 952,
#  'houndstooth': 953,
#  'workout': 954,
#  'windows': 955,
#  'disick': 956,
#  'troubled': 957,
#  'trim': 958,
#  'watchdog': 959,
#  'arctic': 960,
#  'ocean': 961,
#  'collections': 962,
#  'muse': 963,
#  'cork': 964,
#  'brake': 965,
#  'darkest': 966,
#  'tyrant': 967,
#  'parole': 968,
#  'document': 969,
#  'teliasonera': 970,
#  'ramming': 971,
#  'tunnels': 972,
#  'amoeba': 973,
#  'sinatra': 974,
#  '107': 975,
#  'discusses': 976,
#  'families': 977,
#  'action': 978,
#  'massive': 979,
#  'gervais': 980,
#  'employee': 981,
#  'marvel': 982,
#  'pmis': 983,
#  'sonic': 984,
#  'waves': 985,
#  'cinco': 986,
#  'stairway': 987,
#  'lynch': 988,
#  'nails': 989,
#  'valeria': 990,
#  'buyer': 991,
#  'roy': 992,
#  'battling': 993,
#  'truths': 994,
#  'exporters': 995,
#  'observed': 996,
#  'lannister': 997,
#  'surrounding': 998,
#  'insurer': 999,
#  ...}

# %% [markdown]
# ## 81. RNNによる予測

# %%
# %%bash
# pip install torchtext
# Out:
# Collecting torchtext
#   Downloading https://files.pythonhosted.org/packages/f2/17/e7c588245aece7aa93f360894179374830daf60d7ed0bbb59332de3b3b61/torchtext-0.6.0-py3-none-any.whl (64kB)
# Requirement already satisfied: torch in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from torchtext) (1.5.0)
# Collecting tqdm (from torchtext)
#   Downloading https://files.pythonhosted.org/packages/4a/1c/6359be64e8301b84160f6f6f7936bbfaaa5e9a4eab6cbc681db07600b949/tqdm-4.45.0-py2.py3-none-any.whl (60kB)
# Requirement already satisfied: six in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from torchtext) (1.13.0)
# Requirement already satisfied: requests in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from torchtext) (2.23.0)
# Collecting sentencepiece (from torchtext)
#   Downloading https://files.pythonhosted.org/packages/70/59/19d287e3ddb00fa494422acb0ddab9964733e8c1b74fa20e7632a7825510/sentencepiece-0.1.86-cp36-cp36m-macosx_10_6_x86_64.whl (1.1MB)
# Requirement already satisfied: numpy in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from torchtext) (1.18.1)
# Requirement already satisfied: future in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from torch->torchtext) (0.18.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from requests->torchtext) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from requests->torchtext) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from requests->torchtext) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from requests->torchtext) (1.25.7)
# Installing collected packages: tqdm, sentencepiece, torchtext
# Successfully installed sentencepiece-0.1.86 torchtext-0.6.0 tqdm-4.45.0
# You are using pip version 18.1, however version 20.1b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from torchtext import data
import torch
from torch import nn

# %%
class RNN(nn.Module):
    def __init__(
        self,
        num_embeddings,
        embedding_dim=50,
        hidden_size=50,
        output_size=1,
        num_layers=1,
        dropout=0.2
                ):
        super().__init__()
        
        self.emb = nn.Embedding(num_embeddings, embedding_dim, padding_idx=0)
        self.lstm = nn.LSTM(embedding_dim, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.linear = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, h0=None):
        x = self.emb(x)
        x, h = self.lstm(x, h0)
        x = x[:, -1, :]
        x = self.linear(x)
        return x

# %%
TEXT = data.Field(sequential=True, lower=True, batch_first=True)
LABEL = data.Field(sequential=True, lower=True, batch_first=True)

# %%
train, val, test = data.TabularDataset.splits(
    path='../ch06', train='train.txt', validation='valid.txt', test='test.txt',format='tsv',
    fields=[('TEXT', TEXT), ('LABEL', LABEL)]
)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu:0')
train_iter, val_iter, test_iter = data.Iterator.splits(
    (train, val, test), batch_sizes=(64, 64, 64), device=device, repeat=False, sort=False
)

# %%
TEXT.build_vocab(train, min_freq=2)
LABEL.build_vocab(train)
model = RNN(len(TEXT.vocab.stoi)+1, num_layers=2, output_size=4)

# %%
for epoch in range(1):
    model.train()
    for batch in train_iter:
        x, y = batch.TEXT, batch.LABEL
        y_pred = model(x)
        print(y_pred)
        print(y_pred.shape)
# Out:
# tensor([[0.2020, 0.1594, 0.0248, 0.0930],
#         [0.2182, 0.1560, 0.0042, 0.0897],
#         [0.1925, 0.1512, 0.0328, 0.1192],
#         [0.2145, 0.1528, 0.0370, 0.0929],
#         [0.2251, 0.1659, 0.0031, 0.0978],
#         [0.2052, 0.1390, 0.0452, 0.0965],
#         [0.1920, 0.1557, 0.0349, 0.0976],
#         [0.2037, 0.1460, 0.0189, 0.0955],
#         [0.1967, 0.1464, 0.0343, 0.1066],
#         [0.1974, 0.1504, 0.0169, 0.1006],
#         [0.1815, 0.1646, 0.0387, 0.1036],
#         [0.1752, 0.1345, 0.0375, 0.0918],
#         [0.2207, 0.1404, 0.0569, 0.1046],
#         [0.1786, 0.1263, 0.0417, 0.1097],
#         [0.1989, 0.1586, 0.0343, 0.0943],
#         [0.1894, 0.1487, 0.0419, 0.0734],
#         [0.1860, 0.1570, 0.0155, 0.0931],
#         [0.2203, 0.1440, 0.0197, 0.0969],
#         [0.2068, 0.1540, 0.0235, 0.0931],
#         [0.1945, 0.1479, 0.0537, 0.0986],
#         [0.2101, 0.1387, 0.0538, 0.1071],
#         [0.2135, 0.1465, 0.0245, 0.1061],
#         [0.1083, 0.1590, 0.0510, 0.0794],
#         [0.2184, 0.1515, 0.0294, 0.1094],
#         [0.2153, 0.1496, 0.0370, 0.0884],
#         [0.2125, 0.1415, 0.0553, 0.1047],
#         [0.1594, 0.1445, 0.0198, 0.0864],
#         [0.1498, 0.1478, 0.0246, 0.0830],
#         [0.1963, 0.1679, 0.0005, 0.0878],
#         [0.1703, 0.1662, 0.0275, 0.0910],
#         [0.2089, 0.1566, 0.0149, 0.0979],
#         [0.2031, 0.1412, 0.0215, 0.1085],
#         [ 0.2128,  0.1410,  0.0452,  0.1087],
#         [ 0.1976,  0.1583,  0.0036,  0.0978],
#         [ 0.1369,  0.1612,  0.0160,  0.0487],
#         [ 0.1978,  0.1366,  0.0370,  0.1109],
#         [ 0.2049,  0.1718,  0.0035,  0.0968],
#         [ 0.1942,  0.1524,  0.0231,  0.1051],
#         [ 0.2013,  0.1385,  0.0400,  0.0972],
#         [ 0.2110,  0.1445,  0.0162,  0.1101],
#         [ 0.1860,  0.1373,  0.0018,  0.0865],
#         [ 0.1909,  0.1424,  0.0205,  0.0880],
#         [ 0.2013,  0.1572,  0.0261,  0.1193],
#         [ 0.1615,  0.1525,  0.0105,  0.0665],
#         [ 0.1999,  0.1478, -0.0085,  0.1110],
#         [ 0.2058,  0.1466, -0.0079,  0.0921],
#         [ 0.2121,  0.1578,  0.0471,  0.0940],
#         [ 0.1508,  0.1475,  0.0294,  0.0771],
#         [ 0.1982,  0.1406,  0.0177,  0.1100],
#         [ 0.2083,  0.1314,  0.0450,  0.1040],
#         [ 0.1713,  0.1515,  0.0089,  0.0841],
#         [ 0.2194,  0.1368,  0.0381,  0.0959],
#         [ 0.2028,  0.1419,  0.0261,  0.0894],
#         [ 0.1849,  0.1639,  0.0269,  0.0949],
#         [ 0.1993,  0.1544,  0.0336,  0.0916],
#         [ 0.1188,  0.1182,  0.0213,  0.0804],
#         [ 0.1358,  0.1515,  0.0023,  0.0680],
#         [ 0.2007,  0.1544,  0.0138,  0.0889],
#         [ 0.1952,  0.1392,  0.0446,  0.0901],
#         [ 0.2067,  0.1538,  0.0456,  0.0899],
#         [ 0.2082,  0.1644,  0.0115,  0.0957],
#         [ 0.1545,  0.1625,  0.0372,  0.0944],
#         [ 0.2111,  0.1524,  0.0346,  0.0972],
#         [ 0.2111,  0.1538,  0.0372,  0.1067]], grad_fn=<AddmmBackward>)
# torch.Size([48, 4])

# %% [markdown]
# ## 82. 確率的勾配降下法による学習

# %%
# %%bash
# pip install -U catalyst
# Out:
# Collecting catalyst
#   Downloading https://files.pythonhosted.org/packages/a2/96/87158d74688d7d2e3c233f1fd931d86b3ca4663e2d8869e0786463fb79bf/catalyst-20.4.2-py2.py3-none-any.whl (323kB)
# Collecting tensorboard>=1.14.0 (from catalyst)
#   Downloading https://files.pythonhosted.org/packages/1d/fd/4f3ca1516cbb3713259ef229abd9314bba0077ef6070285dde0dd1ed21b2/tensorboard-2.2.1-py3-none-any.whl (3.0MB)
# Requirement already satisfied, skipping upgrade: Pillow in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from catalyst) (7.1.1)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.20 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from catalyst) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.4 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from catalyst) (1.18.1)
# Collecting opencv-python (from catalyst)
#   Downloading https://files.pythonhosted.org/packages/8f/67/d30cb5ee1210c6778a718780d227fa27fa066b46cc25e0b09cd8e51faffe/opencv_python-4.2.0.34-cp36-cp36m-macosx_10_9_x86_64.whl (49.1MB)
# Requirement already satisfied, skipping upgrade: torch>=1.0.0 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from catalyst) (1.5.0)
# Collecting GitPython>=2.1.11 (from catalyst)
#   Downloading https://files.pythonhosted.org/packages/19/1a/0df85d2bddbca33665d2148173d3281b290ac054b5f50163ea735740ac7b/GitPython-3.1.1-py3-none-any.whl (450kB)
# Requirement already satisfied, skipping upgrade: tqdm>=4.33.0 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from catalyst) (4.45.0)
# Collecting tensorboardX (from catalyst)
#   Downloading https://files.pythonhosted.org/packages/35/f1/5843425495765c8c2dd0784a851a93ef204d314fc87bcc2bbb9f662a3ad1/tensorboardX-2.0-py2.py3-none-any.whl (195kB)
# Collecting deprecation (from catalyst)
#   Downloading https://files.pythonhosted.org/packages/02/c3/253a89ee03fc9b9682f1541728eb66db7db22148cd94f89ab22528cd1e1b/deprecation-2.1.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: ipython in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from catalyst) (7.11.1)
# Collecting scikit-image>=0.14.2 (from catalyst)
#   Downloading https://files.pythonhosted.org/packages/cd/6b/f889a95b0eea50b4648c7cf782e339f7f8e46e89023f14b3c685cf86b99f/scikit_image-0.16.2-cp36-cp36m-macosx_10_6_intel.whl (30.4MB)
# Requirement already satisfied, skipping upgrade: PyYAML in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from catalyst) (5.3.1)
# Collecting plotly>=4.1.0 (from catalyst)
#   Downloading https://files.pythonhosted.org/packages/15/90/918bccb0ca60dc6d126d921e2c67126d75949f5da777e6b18c51fb12603d/plotly-4.6.0-py2.py3-none-any.whl (7.1MB)
# Requirement already satisfied, skipping upgrade: pandas>=0.22 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from catalyst) (0.25.3)
# Collecting imageio (from catalyst)
#   Downloading https://files.pythonhosted.org/packages/4c/2b/9dd19644f871b10f7e32eb2dbd6b45149c350b4d5f2893e091b882e03ab7/imageio-2.8.0-py3-none-any.whl (3.3MB)
# Collecting packaging (from catalyst)
#   Downloading https://files.pythonhosted.org/packages/62/0a/34641d2bf5c917c96db0ded85ae4da25b6cd922d6b794648d4e7e07c88e5/packaging-20.3-py2.py3-none-any.whl
# Collecting crc32c>=1.7 (from catalyst)
#   Downloading https://files.pythonhosted.org/packages/a2/e8/8fa6fec83911d304658b5646549e822a0d9d4022931203a842c8a030e31e/crc32c-2.0-cp36-cp36m-macosx_10_6_x86_64.whl
# Requirement already satisfied, skipping upgrade: torchvision>=0.2.1 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from catalyst) (0.6.0)
# Requirement already satisfied, skipping upgrade: matplotlib in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from catalyst) (3.2.1)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from tensorboard>=1.14.0->catalyst) (1.14.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.0 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from tensorboard>=1.14.0->catalyst) (3.11.3)
# Collecting werkzeug>=0.11.15 (from tensorboard>=1.14.0->catalyst)
#   Downloading https://files.pythonhosted.org/packages/cc/94/5f7079a0e00bd6863ef8f1da638721e9da21e5bacee597595b318f71d62e/Werkzeug-1.0.1-py2.py3-none-any.whl (298kB)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from tensorboard>=1.14.0->catalyst) (2.23.0)
# Collecting absl-py>=0.4 (from tensorboard>=1.14.0->catalyst)
#   Downloading https://files.pythonhosted.org/packages/1a/53/9243c600e047bd4c3df9e69cfabc1e8004a82cac2e0c484580a78a94ba2a/absl-py-0.9.0.tar.gz (104kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard>=1.14.0->catalyst)
#   Downloading https://files.pythonhosted.org/packages/7b/b8/88def36e74bee9fce511c9519571f4e485e890093ab7442284f4ffaef60b/google_auth_oauthlib-0.4.1-py2.py3-none-any.whl
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard>=1.14.0->catalyst)
#   Downloading https://files.pythonhosted.org/packages/51/cd/a0c1f9e4582ea64dddf76c1b808b318d01e3b858a51c715bffab1016ecc7/tensorboard_plugin_wit-1.6.0.post3-py3-none-any.whl (777kB)
# Requirement already satisfied, skipping upgrade: grpcio>=1.24.3 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from tensorboard>=1.14.0->catalyst) (1.28.1)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from tensorboard>=1.14.0->catalyst) (1.13.0)
# Collecting wheel>=0.26; python_version >= "3" (from tensorboard>=1.14.0->catalyst)
#   Using cached https://files.pythonhosted.org/packages/8c/23/848298cccf8e40f5bbb59009b32848a4c38f4e7f3364297ab3c3e2e2cd14/wheel-0.34.2-py2.py3-none-any.whl
# Collecting setuptools>=41.0.0 (from tensorboard>=1.14.0->catalyst)
#   Downloading https://files.pythonhosted.org/packages/a0/df/635cdb901ee4a8a42ec68e480c49f85f4c59e8816effbf57d9e6ee8b3588/setuptools-46.1.3-py3-none-any.whl (582kB)
# Collecting markdown>=2.6.8 (from tensorboard>=1.14.0->catalyst)
#   Downloading https://files.pythonhosted.org/packages/ab/c4/ba46d44855e6eb1770a12edace5a165a0c6de13349f592b9036257f3c3d3/Markdown-3.2.1-py2.py3-none-any.whl (88kB)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from scikit-learn>=0.20->catalyst) (0.14.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from scikit-learn>=0.20->catalyst) (1.4.1)
# Requirement already satisfied, skipping upgrade: future in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from torch>=1.0.0->catalyst) (0.18.2)
# Collecting gitdb<5,>=4.0.1 (from GitPython>=2.1.11->catalyst)
#   Downloading https://files.pythonhosted.org/packages/74/52/ca35448b56c53a079d3ffe18b1978c6e424f6d4df02404877094c89f5bfb/gitdb-4.0.4-py3-none-any.whl (63kB)
# Requirement already satisfied, skipping upgrade: appnope; sys_platform == "darwin" in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from ipython->catalyst) (0.1.0)
# Requirement already satisfied, skipping upgrade: pickleshare in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from ipython->catalyst) (0.7.5)
# Requirement already satisfied, skipping upgrade: decorator in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from ipython->catalyst) (4.4.1)
# Requirement already satisfied, skipping upgrade: traitlets>=4.2 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from ipython->catalyst) (4.3.3)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from ipython->catalyst) (2.0.10)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from ipython->catalyst) (0.15.2)
# Requirement already satisfied, skipping upgrade: pygments in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from ipython->catalyst) (2.5.2)
# Requirement already satisfied, skipping upgrade: backcall in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from ipython->catalyst) (0.1.0)
# Requirement already satisfied, skipping upgrade: pexpect; sys_platform != "win32" in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from ipython->catalyst) (4.7.0)
# Collecting PyWavelets>=0.4.0 (from scikit-image>=0.14.2->catalyst)
#   Downloading https://files.pythonhosted.org/packages/28/cd/0d96e765d793ae0e2fa291250ab98c27c0c574b0044c5a6ec3f6ae2afa91/PyWavelets-1.1.1-cp36-cp36m-macosx_10_9_x86_64.whl (4.3MB)
# Collecting networkx>=2.0 (from scikit-image>=0.14.2->catalyst)
#   Downloading https://files.pythonhosted.org/packages/41/8f/dd6a8e85946def36e4f2c69c84219af0fa5e832b018c970e92f2ad337e45/networkx-2.4-py3-none-any.whl (1.6MB)
# Collecting retrying>=1.3.3 (from plotly>=4.1.0->catalyst)
#   Downloading https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from pandas>=0.22->catalyst) (2019.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from pandas>=0.22->catalyst) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from packaging->catalyst) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from matplotlib->catalyst) (1.2.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from matplotlib->catalyst) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14.0->catalyst) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14.0->catalyst) (4.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14.0->catalyst) (4.1.0)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14.0->catalyst) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14.0->catalyst) (2.9)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14.0->catalyst) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14.0->catalyst) (1.25.7)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14.0->catalyst)
#   Downloading https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Collecting smmap<4,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython>=2.1.11->catalyst)
#   Downloading https://files.pythonhosted.org/packages/27/b1/e379cfb7c07bbf8faee29c4a1a2469dbea525f047c2b454c4afdefa20a30/smmap-3.0.2-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: ipython-genutils in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from traitlets>=4.2->ipython->catalyst) (0.2.0)
# Requirement already satisfied, skipping upgrade: wcwidth in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->catalyst) (0.1.8)
# Requirement already satisfied, skipping upgrade: parso>=0.5.2 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from jedi>=0.10->ipython->catalyst) (0.5.2)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython->catalyst) (0.6.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=1.14.0->catalyst) (0.4.8)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14.0->catalyst)
#   Downloading https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
# Installing collected packages: werkzeug, absl-py, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard-plugin-wit, wheel, setuptools, markdown, tensorboard, opencv-python, smmap, gitdb, GitPython, tensorboardX, packaging, deprecation, PyWavelets, networkx, imageio, scikit-image, retrying, plotly, crc32c, catalyst
#   Running setup.py install for absl-py: started
#     Running setup.py install for absl-py: finished with status 'done'
#   Found existing installation: setuptools 40.6.2
#     Uninstalling setuptools-40.6.2:
#       Successfully uninstalled setuptools-40.6.2
#   Running setup.py install for retrying: started
#     Running setup.py install for retrying: finished with status 'done'
# Successfully installed GitPython-3.1.1 PyWavelets-1.1.1 absl-py-0.9.0 catalyst-20.4.2 crc32c-2.0 deprecation-2.1.0 gitdb-4.0.4 google-auth-oauthlib-0.4.1 imageio-2.8.0 markdown-3.2.1 networkx-2.4 oauthlib-3.1.0 opencv-python-4.2.0.34 packaging-20.3 plotly-4.6.0 requests-oauthlib-1.3.0 retrying-1.3.3 scikit-image-0.16.2 setuptools-46.1.3 smmap-3.0.2 tensorboard-2.2.1 tensorboard-plugin-wit-1.6.0.post3 tensorboardX-2.0 werkzeug-1.0.1 wheel-0.34.2
# You are using pip version 18.1, however version 20.1b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import torch
from torch import nn, optim
from torchtext import data
from catalyst.dl import SupervisedRunner
from catalyst.dl.callbacks import AccuracyCallback
from torch.utils.data import DataLoader
from torchtext.data import Iterator
# Out:
# /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
class BucketIteratorWrapper(DataLoader):
    __initialized__ = False

    def __init__(self, iterator: Iterator):
        self.batch_size = iterator.batch_size
        self.num_workers = 1
        self.collate_fn = None
        self.pin_memory = False
        self.drop_last = False
        self.timeout = 0
        self.worker_init_fn = None
        self.sampler = iterator
        self.batch_sampler = iterator
        self.__initialized__ = True

    def __iter__(self):
        return map(lambda batch: {
            'features': batch.TEXT,
            'targets': batch.LABEL,
        }, self.batch_sampler.__iter__())

    def __len__(self):
        return len(self.batch_sampler)

# %%
class RNN(nn.Module):
    def __init__(self, num_embeddings,
                 embedding_dim=50,
                 hidden_size=50,
                 output_size=1,
                 num_layers=1,
                 dropout=0.2):
        super().__init__()
        self.emb = nn.Embedding(num_embeddings, embedding_dim,
                                padding_idx=0)
        self.lstm = nn.LSTM(embedding_dim,
                            hidden_size, num_layers,
                            batch_first=True, dropout=dropout)
        self.linear = nn.Linear(hidden_size, output_size)

    def forward(self, x, h0=None):
        x = self.emb(x)
        x, h = self.lstm(x, h0)
        x = x[:, -1, :]
        x = self.linear(x)
        return x


TEXT = data.Field(sequential=True, lower=True, batch_first=True)
LABELS = data.Field(sequential=False, batch_first=True, use_vocab=False)

train, val, test = data.TabularDataset.splits(
    path='../ch06', train='train.txt',
    validation='valid.txt', test='test.txt', format='tsv',
    fields=[('TEXT', TEXT), ('LABEL', LABELS)])

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
train_iter, val_iter, test_iter = data.BucketIterator.splits(
    (train, val, test), batch_sizes=(len(train), len(val), len(test)), device=device, repeat=False, sort=False)

train_loader = BucketIteratorWrapper(train_iter)
valid_loader = BucketIteratorWrapper(val_iter)
loaders = {"train": train_loader, "valid": valid_loader}

# %%
TEXT.build_vocab(train, min_freq=2)
LABELS.build_vocab(train)

# %%
model = RNN(len(TEXT.vocab.stoi) + 1, num_layers=2, output_size=4)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

runner = SupervisedRunner()

# %%
runner.train(
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    loaders=loaders,
    logdir="./logdir",
    callbacks=[AccuracyCallback(num_classes=4, accuracy_args=[1])],
    num_epochs=10,
    verbose=True,
)
# Out:
# 1/10 * Epoch (train): 100% 1/1 [00:56<00:00, 56.04s/it, accuracy01=0.114, loss=1.410]
# 1/10 * Epoch (valid): 100% 1/1 [00:00<00:00,  8.12it/s, accuracy01=0.114, loss=1.407]
# [2020-04-29 22:55:29,585]
# 1/10 * Epoch 1 (_base): lr=0.0100 | momentum=0.000e+00
# 1/10 * Epoch 1 (train): accuracy01=0.1142 | loss=1.4104
# 1/10 * Epoch 1 (valid): accuracy01=0.1139 | loss=1.4073
# 2/10 * Epoch (train): 100% 1/1 [01:08<00:00, 68.03s/it, accuracy01=0.114, loss=1.408]
# 2/10 * Epoch (valid): 100% 1/1 [00:00<00:00,  8.45it/s, accuracy01=0.114, loss=1.405]
# [2020-04-29 22:56:37,761]
# 2/10 * Epoch 2 (_base): lr=0.0100 | momentum=0.000e+00
# 2/10 * Epoch 2 (train): accuracy01=0.1142 | loss=1.4082
# 2/10 * Epoch 2 (valid): accuracy01=0.1139 | loss=1.4052
# 3/10 * Epoch (train): 100% 1/1 [01:05<00:00, 65.42s/it, accuracy01=0.114, loss=1.406]
# 3/10 * Epoch (valid): 100% 1/1 [00:00<00:00,  5.62it/s, accuracy01=0.114, loss=1.403]
# [2020-04-29 22:57:43,382]
# 3/10 * Epoch 3 (_base): lr=0.0100 | momentum=0.000e+00
# 3/10 * Epoch 3 (train): accuracy01=0.1142 | loss=1.4062
# 3/10 * Epoch 3 (valid): accuracy01=0.1139 | loss=1.4031
# Early exiting
# 4/10 * Epoch (train):   0% 0/1 [01:01<?, ?it/s]

# %% [markdown]
# ## 83. ミニバッチ化・GPU上での学習
# 問題82のコードを改変し，B事例ごとに損失・勾配を計算して学習を行えるようにせよ（Bの値は適当に選べ）．また，GPU上で学習を実行せよ．

# %%
# 82のbatch_sizesを変えるだけなのでスキップ

# %% [markdown]
# ## 84. 単語ベクトルの導入
# 事前学習済みの単語ベクトル（例えば，Google Newsデータセット（約1,000億単語）での学習済み単語ベクトル）で単語埋め込みemb(x)を初期化し，学習せよ．

# %%
import torch
from torch import nn, optim
from torchtext import data
from catalyst.dl import SupervisedRunner
from catalyst.dl.callbacks import AccuracyCallback
from torch.utils.data import DataLoader
from torchtext.data import Iterator
from gensim.models import KeyedVectors
# Out:
# unable to import 'smart_open.gcs', disabling that module
# /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning:
#
# `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.

# %%
class RNN(nn.Module):
    def __init__(self, num_embeddings,
                 embedding_dim=300,
                 hidden_size=300,
                 output_size=1,
                 num_layers=1,
                 dropout=0.2):
        super().__init__()
        model = KeyedVectors.load_word2vec_format('../ch07/GoogleNews-vectors-negative300.bin', binary=True)
        weights = torch.FloatTensor(model.vectors)
        self.emb = nn.Embedding.from_pretrained(weights)
        self.lstm = nn.LSTM(embedding_dim,
                            hidden_size, num_layers,
                            batch_first=True, dropout=dropout)
        self.linear = nn.Linear(hidden_size, output_size)

    def forward(self, x, h0=None):
        x = self.emb(x)
        x, h = self.lstm(x, h0)
        x = x[:, -1, :]
        x = self.linear(x)
        return x

# %%
TEXT = data.Field(sequential=True, lower=True, batch_first=True)
LABELS = data.Field(sequential=False, batch_first=True, use_vocab=False)

train, val, test = data.TabularDataset.splits(
    path='../ch06', train='train.txt',
    validation='valid.txt', test='test.txt', format='tsv',
    fields=[('TEXT', TEXT), ('LABEL', LABELS)])

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

train_iter, val_iter, test_iter = data.BucketIterator.splits(
    (train, val, test), batch_sizes=(len(train), len(val), len(test)), device=device, repeat=False, sort=False)

train_loader = BucketIteratorWrapper(train_iter)
valid_loader = BucketIteratorWrapper(val_iter)
loaders = {"train": train_loader, "valid": valid_loader}

TEXT.build_vocab(train, min_freq=2)
LABELS.build_vocab(train)

model = RNN(len(TEXT.vocab.stoi) + 1, num_layers=2, output_size=4)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

runner = SupervisedRunner()

runner.train(
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    loaders=loaders,
    logdir="./logdir",
    callbacks=[AccuracyCallback(num_classes=4, accuracy_args=[1])],
    num_epochs=10,
    verbose=True,
)

# %% [markdown]
# ## 85. 双方向RNN・多層化Permalink

# %%
import torch
from torch import nn, optim
from torchtext import data
from catalyst.dl import SupervisedRunner
from catalyst.dl.callbacks import AccuracyCallback
from torch.utils.data import DataLoader
from torchtext.data import Iterator
from gensim.models import KeyedVectors
# Out:
# /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# unable to import 'smart_open.gcs', disabling that module
# /Users/shota.kikuchi/.pyenv/versions/3.6.8/lib/python3.6/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning:
#
# `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.

# %%
class BucketIteratorWrapper(DataLoader):
    __initialized__ = False

    def __init__(self, iterator: Iterator):
        self.batch_size = iterator.batch_size
        self.num_workers = 1
        self.collate_fn = None
        self.pin_memory = False
        self.drop_last = False
        self.timeout = 0
        self.worker_init_fn = None
        self.sampler = iterator
        self.batch_sampler = iterator
        self.__initialized__ = True

    def __iter__(self):
        return map(lambda batch: {
            'features': batch.TEXT,
            'targets': batch.LABEL,
        }, self.batch_sampler.__iter__())

    def __len__(self):
        return len(self.batch_sampler)

# %%
class RNN(nn.Module):
    def __init__(self, num_embeddings,
                 embedding_dim=300,
                 hidden_size=300,
                 output_size=1,
                 num_layers=1,
                 dropout=0.2):
        super().__init__()
        model = KeyedVectors.load_word2vec_format('../ch07/GoogleNews-vectors-negative300.bin', binary=True)
        weights = torch.FloatTensor(model.vectors)
        self.emb = nn.Embedding.from_pretrained(weights)
        # enable bidirectional
        self.lstm = nn.LSTM(embedding_dim,
                            hidden_size, num_layers,
                            batch_first=True, dropout=dropout, bidirectional=True)
        # hidden_size * 2
        self.linear = nn.Linear(hidden_size*2, output_size)

    def forward(self, x, h0=None):
        x = self.emb(x)
        x, h = self.lstm(x, h0)
        x = x[:, -1, :]
        x = self.linear(x)
        return x

# %%
TEXT = data.Field(sequential=True, lower=True, batch_first=True)
LABELS = data.Field(sequential=False, batch_first=True, use_vocab=False)

train, val, test = data.TabularDataset.splits(
    path='../ch06', train='train.txt',
    validation='valid.txt', test='test.txt', format='tsv',
    fields=[('TEXT', TEXT), ('LABEL', LABELS)])

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

train_iter, val_iter, test_iter = data.BucketIterator.splits(
    (train, val, test), batch_sizes=(len(train), len(val), len(test)), device=device, repeat=False, sort=False)

train_loader = BucketIteratorWrapper(train_iter)
valid_loader = BucketIteratorWrapper(val_iter)
loaders = {"train": train_loader, "valid": valid_loader}

TEXT.build_vocab(train, min_freq=2)
LABELS.build_vocab(train)

model = RNN(len(TEXT.vocab.stoi) + 1, num_layers=2, output_size=4)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

runner = SupervisedRunner()

runner.train(
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    loaders=loaders,
    logdir="./logdir",
    callbacks=[AccuracyCallback(num_classes=4, accuracy_args=[1])],
    num_epochs=10,
    verbose=True,
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-eea52fe84f7e> in <module>
#      19 LABELS.build_vocab(train)
#      20
# ---> 21 model = RNN(len(TEXT.vocab.stoi) + 1, num_layers=2, output_size=4)
#      22 criterion = nn.CrossEntropyLoss()
#      23 optimizer = optim.SGD(model.parameters(), lr=0.01)
#
# <ipython-input-3-cfa6eb364460> in __init__(self, num_embeddings, embedding_dim, hidden_size, output_size, num_layers, dropout)
#       7                  dropout=0.2):
#       8         super().__init__()
# ----> 9         model = KeyedVectors.load_word2vec_format('../ch07/GoogleNews-vectors-negative300.bin', binary=True)
#      10         weights = torch.FloatTensor(model.vectors)
#      11         self.emb = nn.Embedding.from_pretrained(weights)
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#    1496         return _load_word2vec_format(
#    1497             cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
# -> 1498             limit=limit, datatype=datatype)
#    1499
#    1500     def get_keras_embedding(self, train_embeddings=False):
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/gensim/models/utils_any2vec.py in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#     379                         raise EOFError("unexpected end of input; is count incorrect or file otherwise damaged?")
#     380                     if ch != b'\n':  # ignore newlines in front of words (some binary files have)
# --> 381                         word.append(ch)
#     382                 word = utils.to_unicode(b''.join(word), encoding=encoding, errors=unicode_errors)
#     383                 with utils.ignore_deprecation_warning():
#
# KeyboardInterrupt:

# %% [markdown]
# ## 86. 畳み込みニューラルネットワーク (CNN)

# %%
import torch
from torch import nn, optim
import torch.nn.functional as F
from torchtext import data
from torch.utils.data import DataLoader
from torchtext.data import Iterator
from gensim.models import KeyedVectors


class BucketIteratorWrapper(DataLoader):
    __initialized__ = False

    def __init__(self, iterator: Iterator):
        self.batch_size = iterator.batch_size
        self.num_workers = 1
        self.collate_fn = None
        self.pin_memory = False
        self.drop_last = False
        self.timeout = 0
        self.worker_init_fn = None
        self.sampler = iterator
        self.batch_sampler = iterator
        self.__initialized__ = True

    def __iter__(self):
        return map(lambda batch: {
            'features': batch.TEXT,
            'targets': batch.LABEL,
        }, self.batch_sampler.__iter__())

    def __len__(self):
        return len(self.batch_sampler)

# %%
class CNN(nn.Module):

    def __init__(self, load_model, output_dim, kernel_num, kernel_sizes=[3, 4, 5], dropout=0.5, static=False):
        super(CNN, self).__init__()

#         model = KeyedVectors.load_word2vec_format('../ch07/GoogleNews-vectors-negative300.bin', binary=True)
        model = load_model
        weights = torch.FloatTensor(model.vectors)
        self.embed = nn.Embedding.from_pretrained(weights)
        self.convs1 = nn.ModuleList([nn.Conv2d(1, kernel_num, (k, self.embed.weight.shape[1])) for k in kernel_sizes])
        self.dropout = nn.Dropout(dropout)
        self.fc1 = nn.Linear(len(kernel_sizes) * kernel_num, output_dim)
        self.static = static

    def conv_and_pool(self, x, conv):
        x = F.relu(conv(x)).squeeze(3)
        x = F.max_pool1d(x, x.size(2)).squeeze(2)
        return x

    def forward(self, x):
        x = self.embed(x)
        print(x.size())

        if self.static:
            x = x.detach()

        x = x.unsqueeze(1)
        x = x.float()
        x = [F.relu(conv(x)).squeeze(3) for conv in self.convs1]

        x = [F.max_pool1d(i, i.size(2)).squeeze(2) for i in x]

        x = torch.cat(x, 1)
        x = self.dropout(x)
        logit = self.fc1(x)
        return logit

# %%
load_model = KeyedVectors.load_word2vec_format('../ch07/GoogleNews-vectors-negative300.bin', binary=True)

# %%
model = CNN(load_model, output_dim=4, kernel_num=3, kernel_sizes=[3, 4, 5], dropout=0.2)
print(model)
# Out:
# CNN(
#   (embed): Embedding(3000000, 300)
#   (convs1): ModuleList(
#     (0): Conv2d(1, 3, kernel_size=(3, 300), stride=(1, 1))
#     (1): Conv2d(1, 3, kernel_size=(4, 300), stride=(1, 1))
#     (2): Conv2d(1, 3, kernel_size=(5, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=9, out_features=4, bias=True)
# )

# %%
TEXT = data.Field(sequential=True, lower=True, batch_first=True)
LABELS = data.Field(sequential=False, batch_first=True, use_vocab=False)

train, val, test = data.TabularDataset.splits(
    path='../ch06', train='train.txt',
    validation='valid.txt', test='test.txt', format='tsv',
    fields=[('TEXT', TEXT), ('LABEL', LABELS)])

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
train_iter, val_iter, test_iter = data.BucketIterator.splits(
    (train, val, test), batch_sizes=(64, 64, 64), device=device, repeat=False, sort=False)

train_loader = BucketIteratorWrapper(train_iter)
valid_loader = BucketIteratorWrapper(val_iter)
loaders = {"train": train_loader, "valid": valid_loader}

TEXT.build_vocab(train, min_freq=2)
LABELS.build_vocab(train)
# model = CNN(output_dim=4, kernel_num=3, kernel_sizes=[3, 4, 5], dropout=0.2)
model = CNN(load_model, output_dim=4, kernel_num=3, kernel_sizes=[3, 4, 5], dropout=0.2)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

for epoch in range(1):
    model.train()
    for batch in train_iter:
        x, y = batch.TEXT, batch.LABEL
        y_pred = model(x)
        print(y_pred)
        print(y_pred.shape)
# Out:
# torch.Size([64, 16, 300])
# tensor([[ 1.7179e-01,  1.7355e-01,  1.9457e-02,  3.7832e-01],
#         [ 1.6944e-01,  8.8402e-02,  3.6254e-02,  3.0183e-01],
#         [ 7.7913e-02,  1.1209e-01, -2.9325e-03,  3.0808e-01],
#         [ 1.3456e-01,  1.2476e-01,  4.4395e-02,  3.0155e-01],
#         [ 1.0359e-01,  1.6148e-01,  8.9008e-02,  2.7242e-01],
#         [ 0.1397,  0.0421, -0.0152,  0.3198],
#         [ 0.1740,  0.0963,  0.0419,  0.2275],
#         [ 0.0780,  0.1562,  0.0435,  0.2714],
#         [ 0.1531,  0.1309,  0.0476,  0.2765],
#         [ 0.1364,  0.1526,  0.0420,  0.2981],
#         [ 0.1425,  0.0186,  0.0087,  0.2957],
#         [ 0.1215,  0.1474,  0.0914,  0.2554],
#         [ 0.1250,  0.0043, -0.0444,  0.3067],
#         [ 0.1128,  0.1170,  0.0327,  0.2495],
#         [ 0.2115,  0.1682,  0.0692,  0.3183],
#         [ 0.2015,  0.0823,  0.0429,  0.3189],
#         [ 0.1257,  0.1692,  0.0618,  0.3060],
#         [ 0.1637,  0.0626, -0.0051,  0.3001],
#         [ 0.1052,  0.0881,  0.0021,  0.3070],
#         [ 0.1418,  0.1160,  0.0512,  0.2931],
#         [ 0.0681,  0.1499,  0.0605,  0.2435],
#         [ 0.2272,  0.1920,  0.0738,  0.3169],
#         [ 0.1613,  0.1385,  0.0817,  0.2509],
#         [ 0.1386,  0.1098,  0.0576,  0.2693],
#         [ 0.1285,  0.1198,  0.0575,  0.2358],
#         [ 0.1118,  0.1070,  0.0303,  0.3069],
#         [ 0.1539,  0.0444, -0.0224,  0.3644],
#         [ 0.1778,  0.2087,  0.0866,  0.3114],
#         [ 0.2663,  0.2338,  0.1047,  0.3513],
#         [ 0.0950,  0.1271,  0.0453,  0.2763],
#         [ 0.1081,  0.0424,  0.0117,  0.2605],
#         [ 0.1117,  0.1166,  0.0211,  0.2602],
#         [ 0.1682,  0.2068,  0.0605,  0.3424],
#         [ 0.1791,  0.1478,  0.0691,  0.3186],
#         [ 0.1062,  0.0886,  0.0163,  0.2753],
#         [ 0.0905,  0.1059,  0.0313,  0.3184],
#         [ 0.1936,  0.1226,  0.0331,  0.3359],
#         [ 0.1159,  0.1336,  0.0593,  0.2420],
#         [ 0.1606,  0.1519,  0.0750,  0.2411],
#         [ 0.1317,  0.0803,  0.0053,  0.3179],
#         [ 0.0861,  0.0770,  0.0074,  0.3113],
#         [ 0.1320,  0.1075,  0.0682,  0.2104],
#         [ 0.1854,  0.1396,  0.0317,  0.3069],
#         [ 0.1484,  0.1077,  0.0521,  0.2439],
#         [ 0.1277,  0.1593,  0.0843,  0.2337],
#         [ 0.1513,  0.0369, -0.0385,  0.3459],
#         [ 0.1022,  0.0215,  0.0054,  0.3143],
#         [ 0.1184,  0.0639,  0.0157,  0.3064]], grad_fn=<AddmmBackward>)
# torch.Size([64, 4])
# torch.Size([64, 15, 300])
# tensor([[ 1.4228e-01,  1.5003e-01,  1.4021e-01,  2.0063e-01],
#         [ 1.3947e-01,  1.4696e-01,  2.5176e-02,  3.3270e-01],
#         [ 1.5830e-02,  4.3784e-02, -9.3177e-03,  3.0018e-01],
#         [ 1.2997e-01,  9.8958e-02,  2.4843e-02,  3.3829e-01],
#         [ 1.0530e-01,  8.9517e-02,  4.5148e-02,  2.3040e-01],
#         [ 5.8420e-02,  6.1374e-02, -1.7280e-02,  2.8393e-01],
#         [ 6.7891e-02,  5.6249e-02,  1.3410e-02,  2.3167e-01],
#         [ 5.7999e-02,  3.4606e-02, -4.3908e-02,  3.2787e-01],
#         [ 1.1757e-01,  1.2162e-01,  4.0440e-02,  3.0966e-01],
#         [ 8.3152e-02,  9.9114e-02,  2.4503e-02,  2.8018e-01],
#         [ 1.4281e-01,  5.4900e-04,  1.0902e-02,  2.1301e-01],
#         [ 1.8154e-01,  1.8921e-01,  5.5113e-02,  3.1854e-01],
#         [ 2.0759e-01,  1.7383e-01,  8.9454e-02,  2.9228e-01],
#         [ 1.0703e-01,  9.7427e-02,  3.3888e-02,  2.9001e-01],
#         [ 1.2168e-01,  9.5964e-02,  7.0143e-03,  3.1452e-01],
#         [ 1.1569e-01,  9.1913e-02,  2.2104e-04,  3.4711e-01],
#         [ 1.2441e-01,  6.8724e-02,  1.0720e-02,  2.8398e-01],
#         [ 5.2372e-02,  1.9562e-02, -4.0417e-02,  3.0570e-01],
#         [ 6.1110e-02,  5.1649e-02, -8.7079e-03,  3.1391e-01],
#         [ 1.7466e-01,  9.9217e-02,  1.0681e-02,  3.5778e-01],
#         [ 1.5420e-01,  1.3650e-01,  4.3333e-02,  2.6107e-01],
#         [ 1.8543e-01,  1.4645e-01,  6.6824e-02,  2.9428e-01],
#         [ 2.0693e-01,  1.1868e-01,  7.7144e-02,  2.9829e-01],
#         [ 1.2439e-01,  1.5527e-02,  1.2416e-02,  2.5059e-01],
#         [ 1.3299e-01,  1.0140e-01,  3.2816e-02,  3.3201e-01],
#         [ 1.8972e-01,  4.6083e-02,  1.5342e-02,  3.1165e-01]],
#        grad_fn=<AddmmBackward>)
# torch.Size([64, 4])
# torch.Size([64, 17, 300])
# tensor([[ 0.1009,  0.1093,  0.0497,  0.3021],
#         [ 0.0976,  0.0309, -0.0516,  0.3296],
#         [ 0.1987,  0.1374,  0.0371,  0.3066],
#         [ 0.1448,  0.1628,  0.1023,  0.2334],
#         [ 0.1442,  0.0763,  0.0329,  0.3259],
#         [ 0.1394,  0.1369,  0.0449,  0.2369],
#         [ 0.1695,  0.1430,  0.0643,  0.2944],
#         [ 0.0837,  0.0131, -0.0176,  0.2612],
#         [ 0.1411,  0.0884,  0.0493,  0.2689],
#         [ 0.1014,  0.1661,  0.0511,  0.2582],
#         [ 0.1112, -0.0065, -0.0639,  0.3111],
#         [ 0.1060,  0.0894,  0.0228,  0.3441],
#         [ 0.0938,  0.1137,  0.0321,  0.2878],
#         [ 0.1832,  0.1120,  0.0834,  0.2706],
#         [ 0.0911,  0.1090,  0.0020,  0.3161],
#         [ 0.1178,  0.1216,  0.0382,  0.2772],
#         [ 0.1428,  0.1050,  0.0480,  0.2226],
#         [ 0.0817,  0.1351,  0.0375,  0.2455],
#         [ 0.1667,  0.1695,  0.0838,  0.2986],
#         [ 0.0435,  0.0421, -0.0010,  0.2320],
#         [ 0.1230,  0.1150,  0.0449,  0.2963],
#         [ 0.1660,  0.1393,  0.0684,  0.2800],
#         [ 0.0888,  0.0061,  0.0004,  0.2699],
#         [ 0.0705,  0.0103,  0.0402,  0.2193],
#         [ 0.1320,  0.1692,  0.0911,  0.2464],
#         [ 0.1126,  0.0796,  0.0326,  0.2278],
#         [ 0.0599,  0.0224,  0.0591,  0.2261],
#         [ 0.1136,  0.1173,  0.0707,  0.2608],
#         [ 0.0255,  0.0650, -0.0263,  0.2831],
#         [ 0.1926,  0.1776,  0.1041,  0.2584],
#         [ 0.1715,  0.0391, -0.0137,  0.3108],
#         [ 0.2266,  0.0902,  0.0666,  0.2887],
#         [ 0.1072,  0.1024,  0.1000,  0.1874],
#         [ 0.1393,  0.1247,  0.0126,  0.3234],
#         [ 0.1387,  0.0524,  0.0177,  0.2767],
#         [ 0.1051,  0.0978,  0.0571,  0.2126],
#         [ 0.1514,  0.1262,  0.0220,  0.3120],
#         [ 0.1735,  0.1472,  0.0547,  0.2766],
#         [ 0.1034,  0.0349,  0.0094,  0.2406],
#         [ 0.0670,  0.0799,  0.0481,  0.2038],
#         [ 0.1096,  0.1155,  0.0189,  0.2707],
#         [ 0.0930,  0.1808,  0.0239,  0.3181],
#         [ 0.1662,  0.1040,  0.0581,  0.2123],
#         [ 0.1104,  0.0763,  0.0781,  0.1774],
#         [ 0.1011,  0.1296,  0.0690,  0.2243],
#         [ 0.1598,  0.0593,  0.0314,  0.2832],
#         [ 0.1399,  0.0678,  0.0310,  0.2573],
#         [ 0.1305,  0.1728,  0.0902,  0.2646],
#         [ 0.1159,  0.1639,  0.0587,  0.2861],
#         [ 0.1831,  0.2367,  0.1338,  0.2529],
#         [ 0.0858,  0.1387,  0.0495,  0.2671],
#         [ 0.1442,  0.1086,  0.0150,  0.2820],
#         [ 0.0809,  0.0510,  0.0021,  0.2368],
#         [ 0.1483,  0.1490,  0.0197,  0.3438],
#         [ 0.0693,  0.1498,  0.0472,  0.2715],
#         [ 0.1441,  0.0712, -0.0119,  0.3475],
#         [ 0.1160,  0.1086,  0.0671,  0.2445],
#         [ 0.1663,  0.1697,  0.0699,  0.2505],
#         [ 0.0899,  0.0516, -0.0091,  0.2950],
#         [ 0.1581,  0.1219,  0.0098,  0.3186],
#         [ 0.1409,  0.1272,  0.0712,  0.2760],
#         [ 0.1108,  0.1126,  0.0152,  0.2687],
#         [ 0.1936,  0.0313,  0.0101,  0.2789],
#         [ 0.1133, -0.0696, -0.0852,  0.2839]], grad_fn=<AddmmBackward>)
# torch.Size([64, 4])
# torch.Size([64, 15, 300])
# tensor([[ 1.5130e-01,  4.2586e-02, -1.0501e-02,  2.4186e-01],
#         [ 1.3819e-01,  4.4465e-02,  4.9081e-02,  2.4581e-01],
#         [ 1.7750e-01,  1.1537e-01,  6.8840e-02,  2.6196e-01],
#         [ 1.5870e-01,  1.1802e-01,  4.2818e-02,  2.9159e-01],
#         [ 1.3988e-01,  1.5815e-01,  8.0641e-02,  2.1851e-01],
#         [ 1.4086e-01,  1.4280e-01,  6.2163e-02,  2.6742e-01],
#         [ 1.0332e-01,  1.1676e-01,  3.1559e-02,  3.0557e-01],
#         [ 6.7578e-02,  9.2237e-02,  3.4539e-02,  2.7806e-01],
#         [ 1.5754e-01,  1.3540e-01,  3.9096e-02,  2.8962e-01],
#         [ 1.9987e-01,  1.7102e-01,  6.1001e-02,  2.9269e-01],
#         [ 8.6504e-02,  4.3328e-02, -3.8371e-02,  3.1448e-01],
#         [ 1.4339e-01, -8.4380e-03, -4.2863e-02,  2.9964e-01],
#         [ 9.1148e-02,  5.2610e-02,  3.5865e-02,  2.3165e-01],
#         [ 1.8941e-01,  1.3402e-01,  7.0342e-02,  3.0029e-01],
#         [ 7.3477e-02,  1.1870e-01,  8.0732e-02,  2.3576e-01],
#         [ 1.4862e-01,  7.1774e-02,  5.7891e-02,  2.7866e-01]],
#        grad_fn=<AddmmBackward>)
# torch.Size([64, 4])
# torch.Size([64, 17, 300])
# tensor([[ 0.1645,  0.0824,  0.0247,  0.2382],
#         [ 0.0925,  0.0105,  0.0110,  0.1965],
#         [ 0.2169,  0.1641,  0.0779,  0.2693],
#         [ 0.1329,  0.1056,  0.0391,  0.3029],
#         [ 0.1525,  0.0721,  0.0367,  0.2827],
#         [ 0.1606,  0.0361, -0.0610,  0.3384],
#         [ 0.0552,  0.0397, -0.0177,  0.2987],
#         [ 0.1424,  0.2050,  0.0847,  0.2703],
#         [ 0.1563,  0.0992,  0.0243,  0.3078],
#         [ 0.1362,  0.0955,  0.0328,  0.2902],
#         [ 0.1119,  0.1189,  0.0533,  0.2656],
#         [ 0.1130,  0.0802,  0.0057,  0.2931],
#         [ 0.0516,  0.0800,  0.0161,  0.3032],
#         [ 0.1248,  0.1052,  0.0176,  0.3090],
#         [ 0.0980,  0.1202,  0.0350,  0.2875],
#         [ 0.1073,  0.0197, -0.0132,  0.3139],
#         [ 0.1792,  0.0865,  0.0416,  0.2607],
#         [ 0.1255,  0.1285,  0.0625,  0.2414],
#         [ 0.1762,  0.1661,  0.0611,  0.2811],
#         [ 0.1517,  0.0896,  0.0326,  0.2708],
#         [ 0.1297,  0.1143,  0.0539,  0.2808],
#         [ 0.1180, -0.0464, -0.0245,  0.2793],
#         [ 0.1805,  0.1846,  0.0800,  0.2806],
#         [ 0.1476,  0.1077,  0.0181,  0.3273],
#         [ 0.0391,  0.1085, -0.0072,  0.2631],
#         [ 0.0925,  0.0651,  0.0516,  0.1544],
#         [ 0.1264,  0.0965,  0.0527,  0.2371],
#         [ 0.1319,  0.0946,  0.0507,  0.3049],
#         [ 0.1703,  0.1272,  0.0481,  0.2600],
#         [ 0.1205,  0.0404,  0.0087,  0.2272],
#         [ 0.2140,  0.1268,  0.0477,  0.3104],
#         [ 0.1004,  0.0808,  0.0741,  0.1662],
#         [ 0.1130,  0.1101,  0.0230,  0.2890],
#         [ 0.1021,  0.1666,  0.1027,  0.2441],
#         [ 0.1207,  0.0994,  0.0602,  0.2610],
#         [ 0.1412,  0.0963,  0.0814,  0.2132],
#         [ 0.1919,  0.1532,  0.1184,  0.2370],
#         [ 0.1228,  0.0408,  0.0310,  0.2568],
#         [ 0.1233,  0.1213,  0.0337,  0.2628],
#         [ 0.1333,  0.1292,  0.0403,  0.2481],
#         [ 0.1041,  0.0789,  0.0472,  0.2803],
#         [ 9.7988e-02, -3.9453e-04, -9.0371e-03,  2.7343e-01],
#         [ 1.1591e-01,  1.1190e-01,  3.9494e-02,  2.3353e-01],
#         [ 1.5128e-01,  1.5162e-01,  5.5643e-02,  3.0011e-01],
#         [ 1.8815e-01,  6.5460e-02,  1.9108e-02,  2.7949e-01],
#         [ 1.6977e-01,  3.5382e-02,  3.7342e-02,  2.4799e-01],
#         [ 7.3535e-02,  2.6453e-02, -2.7335e-02,  3.1622e-01]],
#        grad_fn=<AddmmBackward>)
# torch.Size([64, 4])
# torch.Size([64, 16, 300])
# tensor([[ 0.1391,  0.0831,  0.0355,  0.3086],
#         [ 0.1097,  0.0776, -0.0018,  0.3049],
#         [ 0.1076,  0.1179,  0.0269,  0.2908],
#         [ 0.1839,  0.0903, -0.0218,  0.3764],
#         [ 0.2031,  0.1400,  0.1022,  0.2036],
#         [ 0.1684,  0.1598,  0.0271,  0.3524],
#         [ 0.1328,  0.0156, -0.0017,  0.2811],
#         [ 0.1167,  0.2312,  0.1151,  0.2737],
#         [ 0.1609,  0.0529,  0.0206,  0.2824],
#         [ 0.1430,  0.1059,  0.0794,  0.2654],
#         [ 0.1891,  0.1289,  0.0392,  0.2964],
#         [ 0.1111,  0.1109,  0.0249,  0.2653],
#         [ 0.0462,  0.0017,  0.0236,  0.1941],
#         [ 0.1143,  0.0764, -0.0172,  0.3369],
#         [ 0.0777,  0.0822,  0.0025,  0.3056],
#         [ 0.0644,  0.0005, -0.0037,  0.2487],
#         [ 0.0896,  0.1275,  0.0066,  0.3436],
#         [ 0.1187,  0.0795, -0.0255,  0.3551],
#         [ 0.1561,  0.2076,  0.0849,  0.2891],
#         [ 0.1592,  0.1115,  0.0656,  0.2837],
#         [ 0.1107,  0.1493,  0.0366,  0.3187],
#         [ 0.1649,  0.0374, -0.0097,  0.3068],
#         [ 0.1526,  0.2686,  0.1283,  0.2970],
#         [ 0.1721,  0.1124,  0.0401,  0.2868],
#         [ 0.0918,  0.1177,  0.0388,  0.2793],
#         [ 0.1548,  0.0305, -0.0168,  0.2958],
#         [ 0.1128,  0.1220,  0.0608,  0.2306],
#         [ 0.0768,  0.1475,  0.0316,  0.2852],
#         [ 0.0992,  0.0270,  0.0029,  0.2352],
#         [ 0.1280,  0.1695,  0.0484,  0.3054],
#         [ 0.1117,  0.0331,  0.0092,  0.2858],
#         [ 0.0861,  0.1876,  0.0596,  0.2987],
#         [ 0.1844,  0.1475,  0.0999,  0.2771],
#         [ 0.1187,  0.1064,  0.0795,  0.2216],
#         [ 0.0584,  0.0762,  0.0410,  0.1943],
#         [ 0.0581, -0.0259, -0.0282,  0.2897],
#         [ 0.1482,  0.1220,  0.0532,  0.2495],
#         [ 0.1075,  0.0554, -0.0263,  0.3116],
#         [ 0.1287,  0.0784,  0.0503,  0.2292],
#         [ 0.1212,  0.0984,  0.0333,  0.2594],
#         [ 0.0090,  0.0366,  0.0214,  0.2141],
#         [ 0.1176,  0.0890,  0.0121,  0.2739],
#         [ 0.1061,  0.0893,  0.0341,  0.2778],
#         [ 0.2349,  0.1506,  0.0486,  0.3122],
#         [ 0.0983, -0.0343, -0.0437,  0.2791],
#         [ 0.1526,  0.1120,  0.0453,  0.2990],
#         [ 0.1042,  0.1374,  0.0637,  0.2684],
#         [ 0.1298,  0.0860,  0.0250,  0.3133],
#         [ 0.1354,  0.1591,  0.0493,  0.2704],
#         [ 0.1480,  0.1181,  0.0275,  0.2689],
#         [ 0.2200,  0.1682,  0.0684,  0.3169],
#         [ 0.1333,  0.1619,  0.0343,  0.3034],
#         [ 0.0994,  0.0822, -0.0247,  0.3527],
#         [ 0.1438,  0.0236,  0.0462,  0.2212],
#         [ 0.1659,  0.1968,  0.1200,  0.2193],
#         [ 0.1286,  0.0410,  0.0214,  0.2265],
#         [ 0.1205,  0.1107,  0.0289,  0.3014],
#         [ 0.2077,  0.1432,  0.0808,  0.2922],
#         [ 0.1694,  0.1566,  0.0244,  0.3154],
#         [ 0.1857,  0.1046,  0.0659,  0.2499],
#         [ 0.1219,  0.1367,  0.0269,  0.3233],
#         [ 0.1792,  0.1263,  0.0978,  0.2362],
#         [ 0.1475,  0.1452,  0.0693,  0.2664],
#         [ 0.1897,  0.1240,  0.0602,  0.3149],
#         [ 0.1573,  0.2091,  0.0847,  0.2920],
#         [ 0.0798, -0.0062, -0.0342,  0.3258],
#         [ 0.1369,  0.1191,  0.0528,  0.2922],
#         [ 0.0534,  0.0459, -0.0119,  0.2777],
#         [ 0.1698,  0.2007,  0.0872,  0.2609],
#         [ 0.1005,  0.0872,  0.0069,  0.3075],
#         [ 0.1882,  0.1242,  0.0077,  0.3532],
#         [ 0.1703,  0.1848,  0.0807,  0.3267],
#         [ 0.1875,  0.1818,  0.0723,  0.2905],
#         [ 0.0840,  0.1042,  0.0308,  0.2682],
#         [ 0.1713,  0.1181,  0.0597,  0.3259],
#         [ 0.0361,  0.0483,  0.0264,  0.2426],
#         [ 0.0602,  0.1039,  0.0311,  0.2640],
#         [ 0.1352,  0.1183,  0.0713,  0.2980],
#         [ 0.1513,  0.0823,  0.0423,  0.2860],
#         [ 0.0638,  0.0274,  0.0015,  0.2973],
#         [ 0.1218,  0.0753, -0.0095,  0.2699],
#         [ 0.1169,  0.0444,  0.0073,  0.2911],
#         [ 0.1302,  0.0559, -0.0104,  0.3090],
#         [ 0.1291,  0.1380, -0.0204,  0.3599],
#         [ 0.1252,  0.2095,  0.1233,  0.2588],
#         [ 0.1768,  0.1653,  0.0780,  0.2720],
#         [ 0.1570,  0.0031, -0.0082,  0.2865]], grad_fn=<AddmmBackward>)
# torch.Size([64, 4])
# torch.Size([64, 17, 300])
# tensor([[ 0.1394,  0.0664,  0.0151,  0.2254],
#         [ 0.1641,  0.1392,  0.0246,  0.3276],
#         [ 0.2021,  0.1184,  0.0695,  0.3119],
#         [ 0.1373,  0.0729, -0.0035,  0.2998],
#         [ 0.0333,  0.0666, -0.0094,  0.2997],
#         [ 0.0287,  0.0189, -0.0248,  0.2553],
#         [ 0.0549,  0.1161,  0.0505,  0.2551],
#         [ 0.1324,  0.1479,  0.0701,  0.3053],
], grad_fn=<AddmmBackward>)
# torch.Size([64, 4])
# torch.Size([64, 17, 300])
# tensor([[ 0.1971,  0.1276,  0.0072,  0.3267],
#         [ 0.1723,  0.0716,  0.0170,  0.2905],
#         [ 0.1593,  0.1347,  0.0831,  0.3108],
#         [ 0.1209,  0.1346,  0.0710,  0.2523],
#         [ 0.2102,  0.1105,  0.0639,  0.2689],
#         [ 0.1200,  0.1081,  0.0448,  0.2426],
#         [ 0.0930,  0.0603,  0.0157,  0.2796],
#         [ 0.1353,  0.0705, -0.0062,  0.3056],
#         [ 0.0919,  0.1227,  0.0369,  0.2471],
#         [ 0.2113,  0.1643,  0.0923,  0.2768],
#         [ 0.1115,  0.0640, -0.0024,  0.2961],
#         [ 0.1978,  0.1038,  0.0328,  0.3151],
#         [ 0.1553,  0.0864, -0.0008,  0.3067],
#         [ 0.0885,  0.1589,  0.0762,  0.2261],
#         [ 0.1777,  0.1012,  0.0522,  0.2582],
#         [ 0.1087,  0.0900,  0.0136,  0.2910],
#         [ 0.0644,  0.0694,  0.0291,  0.2597],
#         [ 0.0993,  0.0847,  0.0070,  0.3225],
#         [ 0.1902,  0.1637,  0.0860,  0.2746],
#         [ 0.1394,  0.1323,  0.0308,  0.3218],
#         [ 0.1289,  0.1233, -0.0039,  0.2908],
#         [ 0.1277,  0.0549,  0.0537,  0.2378],
#         [ 0.0349,  0.1244,  0.0442,  0.2580],
#         [ 0.0885,  0.0966,  0.0607,  0.2105],
#         [ 0.2156,  0.1407,  0.0761,  0.2759],
#         [ 0.0792,  0.0068,  0.0110,  0.2718],
#         [ 0.1688,  0.1064,  0.0522,  0.2881],
#         [ 0.1124,  0.0758,  0.0041,  0.2908],
#         [ 0.1199,  0.0652, -0.0308,  0.3493],
#         [ 0.1576,  0.1598,  0.0585,  0.2650],
#         [ 0.1565,  0.1136,  0.0620,  0.2890],
#         [ 0.1035,  0.0498,  0.0080,  0.2970],
#         [ 0.0988,  0.0727, -0.0207,  0.3669],
#         [ 0.1602,  0.1766,  0.0492,  0.3354],
#         [ 0.1489,  0.1215,  0.0377,  0.3176],
#         [ 0.1391, -0.0121, -0.0080,  0.2222],
#         [ 0.1881,  0.1308,  0.0656,  0.2911],
#         [ 0.1192,  0.1126,  0.0543,  0.3001],
#         [ 0.1710,  0.0971,  0.0408,  0.2821],
#         [ 0.1169,  0.1474,  0.0552,  0.2871],
#         [ 0.1412,  0.0867,  0.0134,  0.2935],
#         [ 0.1498,  0.1406,  0.0892,  0.2442],
#         [ 0.2006,  0.1085,  0.0522,  0.2570],
#         [ 0.1545,  0.1512,  0.1047,  0.2536],
#         [ 0.2003,  0.0833,  0.0313,  0.3023],
#         [ 0.1929,  0.1346,  0.0487,  0.2750],
#         [ 0.1281,  0.1358,  0.0601,  0.3176],
#         [ 0.1015,  0.0532,  0.0100,  0.3302],
#         [ 0.0855,  0.1512,  0.0521,  0.2685],
#         [ 0.0887,  0.0934, -0.0169,  0.3641],
#         [ 0.0599, -0.0077, -0.0201,  0.2955],
#         [ 0.1466,  0.0744, -0.0051,  0.3144],
#         [ 0.1335,  0.0594,  0.0375,  0.2537],
#         [ 0.0808,  0.0765, -0.0195,  0.3015],
#         [ 0.1545,  0.0523, -0.0025,  0.2836],
#         [ 0.1467,  0.0447,  0.0085,  0.2758],
#         [ 0.1379,  0.1772,  0.0607,  0.2725],
#         [ 0.1473,  0.0750, -0.0045,  0.2508],
#         [ 0.1665,  0.1011,  0.0185,  0.3325],
#         [ 0.1591,  0.1931,  0.0848,  0.2889],
#         [ 0.1510,  0.1097,  0.1064,  0.2124],
#         [ 0.1170,  0.0492,  0.0201,  0.2819],
#         [ 0.1802,  0.0830,  0.0290,  0.3204],
#         [ 0.1208,  0.1122,  0.1067,  0.2427],
#         [ 0.1281,  0.0440, -0.0171,  0.2983],
#         [ 0.1904,  0.1040,  0.0472,  0.2682],
#         [ 0.1145,  0.0832,  0.0278,  0.2678],
#         [ 0.1396,  0.1225,  0.0554,  0.3034],
#         [ 0.1622,  0.1334,  0.0489,  0.2976],
#         [ 0.0894,  0.1263,  0.0376,  0.3485],
#         [ 0.1348,  0.0298,  0.0146,  0.2661],
#         [ 0.1285,  0.1340,  0.0775,  0.2776],
#         [ 0.1658,  0.0810,  0.0804,  0.2597],
#         [ 0.1302,  0.0469, -0.0316,  0.3107],
#         [ 0.1456,  0.1375,  0.0600,  0.3085]], grad_fn=<AddmmBackward>)
# torch.Size([64, 4])
# torch.Size([64, 16, 300])
# tensor([[ 1.9891e-01,  8.1246e-02,  8.0164e-02,  2.8479e-01],
#         [ 1.1107e-01,  1.1482e-01,  4.7581e-02,  2.7242e-01],
#         [ 9.3898e-02,  1.7698e-01,  8.5844e-02,  2.4649e-01],
#         [ 1.1147e-01,  1.6263e-01,  3.3133e-02,  2.7328e-01],
#         [ 1.2215e-01,  2.3293e-02,  1.2294e-02,  2.8912e-01],
#         [ 1.4810e-01,  1.4101e-01,  1.1816e-01,  2.2870e-01],
#         [ 1.6765e-01,  1.7335e-01,  4.0735e-02,  3.0328e-01],
#         [ 1.1306e-01,  7.3948e-02,  3.8534e-02,  2.7051e-01],
#         [ 1.2946e-01,  1.0950e-01,  2.2978e-02,  3.1818e-01],
# ...
#         [ 0.1952,  0.1050,  0.0217,  0.3578],
#         [ 0.0730,  0.0462, -0.0023,  0.3388],
#         [ 0.0666,  0.0773, -0.0138,  0.3080],
#         [ 0.1430,  0.0807,  0.0734,  0.2729],
#         [ 0.1141,  0.2151,  0.1215,  0.2323],
#         [ 0.0901,  0.1550,  0.0341,  0.3323],
#         [ 0.1510,  0.1034,  0.0314,  0.2923],
#         [ 0.0664,  0.1758,  0.0164,  0.3376],
#         [ 0.1729,  0.0664, -0.0150,  0.3096],
#         [ 0.0819,  0.0411, -0.0019,  0.2527],
#         [ 0.0181,  0.0564,  0.0057,  0.2130],
#         [ 0.2025,  0.1923,  0.1043,  0.2732],
#         [ 0.1127,  0.1011,  0.0305,  0.2977],
#         [ 0.0469,  0.0307, -0.0875,  0.3207],
#         [ 0.1045,  0.1506,  0.0766,  0.2678],
#         [ 0.1189,  0.0819,  0.0062,  0.2991],
#         [ 0.0950,  0.0092, -0.0208,  0.2576],
#         [ 0.0850,  0.1416,  0.0587,  0.2784],
#         [ 0.1989,  0.1012,  0.0413,  0.3373],
#         [ 0.2084,  0.1877,  0.0594,  0.3486],
#         [ 0.0729,  0.0386,  0.0313,  0.2392],
#         [ 0.1317,  0.1496,  0.0812,  0.2553],
#         [ 0.1306,  0.0890,  0.0478,  0.2597],
#         [ 0.1016,  0.0909,  0.0073,  0.2681],
#         [ 0.1805,  0.0947,  0.0037,  0.3272],
#         [ 0.1650,  0.1442,  0.0633,  0.2622],
#         [ 0.1275,  0.1144,  0.0309,  0.2819],
#         [ 0.1929,  0.1198,  0.0541,  0.3414],
#         [ 0.1528,  0.1235,  0.0528,  0.2875],
#         [ 0.1330,  0.1540,  0.0552,  0.2501],
#         [ 0.1389,  0.0720,  0.0311,  0.3058],
#         [ 0.1730,  0.0920,  0.0229,  0.3093],
#         [ 0.1334,  0.0948,  0.0709,  0.2691],
#         [ 0.1798,  0.1060,  0.0117,  0.3016],
#         [ 0.1677,  0.0884,  0.0527,  0.2882],
#         [ 0.1838,  0.1119,  0.0316,  0.2733],
#         [ 0.0985,  0.0807,  0.0302,  0.2754],
#         [ 0.1408,  0.1280,  0.0607,  0.2719],
#         [ 0.0881,  0.0639,  0.0630,  0.2159],
#         [ 0.1508,  0.1295,  0.0226,  0.3060],
#         [ 0.1605,  0.1248,  0.0248,  0.3035],
#         [ 0.1595,  0.1789,  0.0438,  0.3476],
#         [ 0.2456,  0.1375,  0.1198,  0.2608],
#         [ 0.0963,  0.1310,  0.0729,  0.2123],
#         [ 0.0280,  0.0898,  0.0492,  0.2322],
#         [ 0.1292,  0.0480,  0.0596,  0.1756],
#         [ 0.0957,  0.1302,  0.0667,  0.2995],
#         [ 0.1785,  0.0804,  0.0431,  0.3116],
#         [ 0.0790,  0.1058,  0.0195,  0.2851],
#         [ 0.1437,  0.0995,  0.0285,  0.2954],
#         [ 0.0999,  0.0675,  0.0251,  0.2165],
#         [ 0.1310,  0.1003,  0.0047,  0.2872],
#         [ 0.1660,  0.1390,  0.0641,  0.3158],
#         [ 0.1084,  0.0690,  0.0047,  0.3500],
#         [ 0.1272,  0.0622,  0.0241,  0.2760],
#         [ 0.1465,  0.1311,  0.0564,  0.2600],
#         [ 0.1011,  0.0100, -0.0378,  0.3000],
#         [ 0.1606,  0.1334,  0.0933,  0.2490],
#         [ 0.1184,  0.0408,  0.0227,  0.2505]], grad_fn=<AddmmBackward>)
# torch.Size([64, 4])
# torch.Size([64, 16, 300])
# tensor([[ 0.1379,  0.0717, -0.0147,  0.2981],
#         [ 0.1079,  0.1262,  0.0360,  0.2718],
#         [ 0.1309,  0.1144,  0.0867,  0.2201],
#         [ 0.0762,  0.0404,  0.0097,  0.2413],
#         [ 0.1033,  0.0514,  0.0382,  0.2333],
#         [ 0.1765,  0.0712,  0.0092,  0.2443],
#         [ 0.1199,  0.0239,  0.0169,  0.2376],
#         [ 0.1826,  0.1567,  0.0513,  0.2895],
#         [ 0.1439,  0.0583, -0.0193,  0.3461],
#         [ 0.1410,  0.1299,  0.0138,  0.3033],
#         [ 0.1332,  0.0767,  0.0463,  0.2447],
#         [ 0.1188,  0.0679,  0.0547,  0.2710],
#         [ 0.0668,  0.0709,  0.0149,  0.2781],
#         [ 0.1120,  0.0997,  0.0131,  0.2822],
#         [ 0.1424,  0.0441, -0.0343,  0.3450],
#         [ 0.1500,  0.1003,  0.0250,  0.2848],
#         [ 0.1500,  0.0408, -0.0222,  0.3752],
#         [ 0.1870,  0.1245,  0.0087,  0.3722],
#         [ 0.0899,  0.0713,  0.0293,  0.2809],
#         [ 0.1148,  0.1153,  0.0576,  0.3009],
#         [ 0.1208,  0.0826,  0.0304,  0.2775],
#         [ 0.1375,  0.0561, -0.0128,  0.3232],
#         [ 0.1466,  0.0926, -0.0231,  0.3214],
#         [ 0.1340,  0.1227, -0.0009,  0.2659],
#         [ 0.0809,  0.1153,  0.0575,  0.1915],
#         [ 0.1730,  0.1419,  0.0429,  0.3249],
#         [ 0.1086,  0.0990,  0.0474,  0.2866],
#         [ 0.0761,  0.0789,  0.0015,  0.2902],
#         [ 0.1668,  0.1105,  0.0398,  0.2763],
#         [ 0.1982,  0.1663,  0.0386,  0.3227],
#         [ 0.1198,  0.1475,  0.0381,  0.3086],
#         [ 0.0641,  0.0792,  0.0313,  0.2441],
#         [ 0.1965,  0.1177,  0.0299,  0.2900],
#         [ 0.1375,  0.0761,  0.0018,  0.3135],
#         [ 0.1421,  0.0314, -0.0174,  0.2900],
#         [ 0.0798,  0.0596, -0.0204,  0.3329],
#         [ 0.1569,  0.1178,  0.0425,  0.2987],
#         [ 0.1903,  0.1202,  0.0435,  0.3052],
#         [ 0.0869,  0.1558,  0.0789,  0.2718],
#         [ 0.1556,  0.1308,  0.0639,  0.2740],
#         [ 0.0965,  0.0638, -0.0149,  0.3311],
#         [ 0.1402,  0.1030,  0.0424,  0.2546],
#         [ 0.0970,  0.0638,  0.0174,  0.2978],
#         [ 0.0862,  0.0623, -0.0119,  0.2960],
#         [ 0.0995,  0.0337,  0.0134,  0.2241],
#         [ 0.1182,  0.1193,  0.0199,  0.3201],
#         [ 0.2006,  0.1946,  0.1043,  0.2414],
#         [ 0.1529,  0.0519, -0.0006,  0.2897],
#         [ 0.1404,  0.0943,  0.0638,  0.2534],
#         [ 0.0722,  0.1636,  0.1125,  0.2142],
#         [ 0.0851,  0.1240,  0.0316,  0.3578],
#         [ 0.1094,  0.0569,  0.0221,  0.2564],
#         [ 0.1067,  0.0106, -0.0466,  0.3195],
#         [ 0.1536,  0.1300,  0.0397,  0.2928],
#         [ 0.1412,  0.0857,  0.0229,  0.2787],
#         [ 0.1424,  0.0803,  0.0119,  0.2631],
#         [ 0.1283,  0.0951,  0.0321,  0.2724],
#         [ 0.1533,  0.1119,  0.0382,  0.3015],
#         [ 0.0942, -0.0005, -0.0242,  0.2668],
#         [ 0.1219,  0.1503,  0.0789,  0.2741],
#         [ 0.0571,  0.0886,  0.0229,  0.2600],
#         [ 0.1621,  0.2101,  0.0669,  0.3223],
#         [ 0.1350,  0.0750,  0.0325,  0.3122],
#         [ 0.1614,  0.0766,  0.0672,  0.2540]], grad_fn=<AddmmBackward>)
# torch.Size([64, 4])
# torch.Size([64, 16, 300])
# tensor([[ 0.1598,  0.1032, -0.0015,  0.3453],
#         [ 0.1391,  0.0372, -0.0125,  0.2763],
#         [ 0.1137,  0.1274,  0.0506,  0.2987],
#         [ 0.1717,  0.0554,  0.0437,  0.2745],
#         [ 0.1556,  0.1420,  0.0421,  0.3578],
#         [ 0.1447,  0.1927,  0.1602,  0.2290],
#         [ 0.1073,  0.0958,  0.0620,  0.2185],
#         [ 0.1701,  0.0706,  0.0094,  0.2552],
#         [ 0.1125,  0.1121,  0.0089,  0.3283],
#         [ 0.1333,  0.0831,  0.0491,  0.2185],
#         [ 0.1836,  0.1454,  0.0823,  0.2820],
#         [ 0.0720,  0.0169, -0.0021,  0.2537],
#         [ 0.1202,  0.0954, -0.0218,  0.3675],
#         [ 0.1865,  0.1379,  0.0650,  0.2980],
#         [ 0.0900,  0.1050,  0.0150,  0.3262],
#         [ 0.1382,  0.1143,  0.0244,  0.3108],
#         [ 0.0629,  0.0180, -0.0126,  0.2904],
#         [ 0.0943,  0.0134,  0.0689,  0.2172],
#         [ 0.1198,  0.0993,  0.0416,  0.2940],
#         [ 0.0329,  0.0172,  0.0115,  0.2677],
#         [ 0.1264,  0.0513,  0.0091,  0.2712],
#         [ 0.0939,  0.1451,  0.0714,  0.2669],
#         [ 0.1521,  0.0940,  0.0231,  0.2553],
#         [ 0.1129,  0.1397,  0.0477,  0.2942],
#         [ 0.1492,  0.1689,  0.0609,  0.2942],
#         [ 0.2141,  0.1069,  0.0449,  0.2629],
#         [ 0.1818,  0.1378,  0.0449,  0.2988],
#         [ 0.1467,  0.1273,  0.0774,  0.2548],
#         [ 0.1985,  0.1478,  0.0868,  0.3004],
#         [ 0.1058,  0.0867, -0.0098,  0.2575],
#         [ 0.0976,  0.1575,  0.0923,  0.2317],
#         [ 0.1975,  0.0970,  0.0309,  0.3252],
#         [ 0.0841,  0.0943,  0.0213,  0.2804],
#         [ 0.1145,  0.0794,  0.0527,  0.2410],
#         [ 0.1467,  0.1415,  0.0015,  0.3815],
#         [ 0.0999,  0.1328,  0.0238,  0.2768],
#         [ 0.1642,  0.1317,  0.0452,  0.3096],
#         [ 0.0425,  0.0076, -0.0388,  0.2313],
#         [ 0.1579,  0.1119,  0.0494,  0.2642],
#         [ 0.1489,  0.1062,  0.0384,  0.2811],
#         [ 0.1656,  0.1173,  0.0590,  0.2458],
#         [ 0.2096,  0.1521,  0.0609,  0.3232],
#         [ 0.1255,  0.1198,  0.0449,  0.2440],
#         [ 0.1135,  0.1164,  0.0721,  0.2551],
#         [ 0.1689,  0.1134,  0.0499,  0.2346],
#         [ 0.2001,  0.1725,  0.0715,  0.3175],
#         [ 0.1349,  0.0511,  0.0089,  0.2887],
#         [ 0.1916,  0.1339,  0.0520,  0.2767],
#         [ 0.1365,  0.0433,  0.0051,  0.2719],
#         [ 0.1464,  0.1233,  0.0808,  0.2355],
#         [ 0.1329,  0.1343,  0.0086,  0.3855],
#         [ 0.1542,  0.0890,  0.0210,  0.3048],
#         [ 0.1478,  0.1272,  0.0421,  0.3280],
#         [ 0.1144,  0.1591,  0.0220,  0.3678],
#         [ 0.1091,  0.0876,  0.0484,  0.2742],
#         [ 0.1288,  0.1496,  0.1040,  0.2524],
#         [ 0.0870,  0.1474,  0.0323,  0.2779],
#         [ 0.1441,  0.0971,  0.0433,  0.2748],
#         [ 0.0811,  0.0717, -0.0024,  0.3274],
#         [ 0.1655,  0.1145, -0.0035,  0.3190],
#         [ 0.0750,  0.0441,  0.0059,  0.2830],
#         [ 0.0964,  0.0557,  0.0259,  0.2203],
#         [ 0.1326,  0.1977,  0.0501,  0.2970],
#         [ 0.1838,  0.0658,  0.0257,  0.3114]], grad_fn=<AddmmBackward>)
# torch.Size([64, 4])

# %%
# class CNN(nn.Module):

#     def __init__(self, load_model, output_dim, kernel_num, kernel_sizes=[3, 4, 5], dropout=0.5, static=False):
#         super(CNN, self).__init__()

# #         model = KeyedVectors.load_word2vec_format('../ch07/GoogleNews-vectors-negative300.bin', binary=True)
#         model = load_model
#         weights = torch.FloatTensor(model.vectors)
#         self.embed = nn.Embedding.from_pretrained(weights)
#         self.convs1 = nn.ModuleList([nn.Conv2d(1, kernel_num, (k, self.embed.weight.shape[1])) for k in kernel_sizes])
#         self.dropout = nn.Dropout(dropout)
#         self.fc1 = nn.Linear(len(kernel_sizes) * kernel_num, output_dim)
#         self.static = static

#     def conv_and_pool(self, x, conv):
#         x = F.relu(conv(x)).squeeze(3)
#         x = F.max_pool1d(x, x.size(2)).squeeze(2)
#         return x

#     def forward(self, x):
#         x = self.embed(x)
#         print(x.size())

#         if self.static:
#             x = x.detach()

#         x = x.unsqueeze(1)
#         print(x.size())
#         x = x.float()
#         z = [F.relu(conv(x)) for conv in self.convs1]
#         print('z')
#         print(z[0].size())
#         print(z[1].size())
#         print(z[2].size())
#         x = [F.relu(conv(x)).squeeze(3) for conv in self.convs1]
#         print('conv2d')
#         print(x[0].size())
#         print(x[1].size())
#         print(x[2].size())

#         x = [F.max_pool1d(i, i.size(2)).squeeze(2) for i in x]
        
#         print('max pooling')
#         print(x[0].size())
#         print(x[1].size())
#         print(x[2].size())

#         x = torch.cat(x, 1)
#         print(x.size())
#         x = self.dropout(x)
#         logit = self.fc1(x)
#         print(logit.size())
#         return logit

# %%
# model = CNN(load_model, output_dim=4, kernel_num=3, kernel_sizes=[3, 4, 5], dropout=0.2)

# %%
# model(x)

# %% [markdown]
# ## 87.確率的勾配降下法

# %%
runner = SupervisedRunner()

runner.train(
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    loaders=loaders,
    logdir="./logdir",
    callbacks=[AccuracyCallback(num_classes=4, accuracy_args=[1])],
    num_epochs=10,
    verbose=True,
)
# Out:
# 1/10 * Epoch (train):   0% 0/167 [00:00<?, ?it/s]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   0% 0/167 [00:00<?, ?it/s, accuracy01=0.125, loss=1.368]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   1% 1/167 [00:00<00:15, 10.86it/s, accuracy01=0.078, loss=1.407]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   2% 3/167 [00:00<00:06, 24.16it/s, accuracy01=0.094, loss=1.373]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   2% 3/167 [00:00<00:06, 24.16it/s, accuracy01=0.109, loss=1.378]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   2% 4/167 [00:00<00:06, 24.16it/s, accuracy01=0.125, loss=1.371]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   3% 5/167 [00:00<00:06, 24.16it/s, accuracy01=0.125, loss=1.391]torch.Size([64, 18, 300])
# torch.Size([64, 1, 18, 300])
# z
# torch.Size([64, 3, 16, 1])
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# conv2d
# torch.Size([64, 3, 16])
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   4% 7/167 [00:00<00:06, 25.60it/s, accuracy01=0.125, loss=1.410]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   4% 7/167 [00:00<00:06, 25.60it/s, accuracy01=0.078, loss=1.401]torch.Size([64, 20, 300])
# torch.Size([64, 1, 20, 300])
# z
# torch.Size([64, 3, 18, 1])
# torch.Size([64, 3, 17, 1])
# torch.Size([64, 3, 16, 1])
# conv2d
# torch.Size([64, 3, 18])
# torch.Size([64, 3, 17])
# torch.Size([64, 3, 16])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   5% 8/167 [00:00<00:06, 25.60it/s, accuracy01=0.078, loss=1.396]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   6% 10/167 [00:00<00:06, 24.82it/s, accuracy01=0.188, loss=1.350]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   6% 10/167 [00:00<00:06, 24.82it/s, accuracy01=0.094, loss=1.389]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   7% 11/167 [00:00<00:06, 24.82it/s, accuracy01=0.078, loss=1.394]torch.Size([64, 18, 300])
# torch.Size([64, 1, 18, 300])
# z
# torch.Size([64, 3, 16, 1])
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# conv2d
# torch.Size([64, 3, 16])
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   8% 13/167 [00:00<00:06, 24.88it/s, accuracy01=0.109, loss=1.408]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   8% 13/167 [00:00<00:06, 24.88it/s, accuracy01=0.094, loss=1.375]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   8% 14/167 [00:00<00:06, 24.88it/s, accuracy01=0.125, loss=1.383]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):   9% 15/167 [00:00<00:06, 24.88it/s, accuracy01=0.109, loss=1.398]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  10% 17/167 [00:00<00:05, 26.64it/s, accuracy01=0.047, loss=1.408]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  10% 17/167 [00:00<00:05, 26.64it/s, accuracy01=0.047, loss=1.404]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  11% 18/167 [00:00<00:05, 26.64it/s, accuracy01=0.141, loss=1.390]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  11% 19/167 [00:00<00:05, 26.64it/s, accuracy01=0.109, loss=1.392]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  13% 21/167 [00:00<00:05, 28.20it/s, accuracy01=0.125, loss=1.364]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  13% 21/167 [00:00<00:05, 28.20it/s, accuracy01=0.125, loss=1.386]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  13% 22/167 [00:00<00:05, 28.20it/s, accuracy01=0.062, loss=1.416]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  14% 23/167 [00:00<00:05, 28.20it/s, accuracy01=0.125, loss=1.364]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  15% 25/167 [00:00<00:04, 29.62it/s, accuracy01=0.109, loss=1.377]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  15% 25/167 [00:00<00:04, 29.62it/s, accuracy01=0.094, loss=1.407]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  16% 26/167 [00:00<00:04, 29.62it/s, accuracy01=0.062, loss=1.403]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  16% 27/167 [00:00<00:04, 29.62it/s, accuracy01=0.141, loss=1.384]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):
torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  68% 113/167 [00:03<00:01, 31.24it/s, accuracy01=0.094, loss=1.410]torch.Size([64, 201, 300])
# torch.Size([64, 1, 201, 300])
# z
# torch.Size([64, 3, 199, 1])
# torch.Size([64, 3, 198, 1])
# torch.Size([64, 3, 197, 1])
# conv2d
# torch.Size([64, 3, 199])
# torch.Size([64, 3, 198])
# torch.Size([64, 3, 197])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# ...
# 1/10 * Epoch (train):  96% 160/167 [00:05<00:00, 30.47it/s, accuracy01=0.125, loss=1.389]torch.Size([64, 19, 300])
# torch.Size([64, 1, 19, 300])
# z
# torch.Size([64, 3, 17, 1])
# torch.Size([64, 3, 16, 1])
# torch.Size([64, 3, 15, 1])
# conv2d
# torch.Size([64, 3, 17])
# torch.Size([64, 3, 16])
# torch.Size([64, 3, 15])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  96% 161/167 [00:05<00:00, 30.47it/s, accuracy01=0.078, loss=1.392]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  97% 162/167 [00:05<00:00, 30.47it/s, accuracy01=0.141, loss=1.373]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  98% 164/167 [00:05<00:00, 29.60it/s, accuracy01=0.172, loss=1.357]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  98% 164/167 [00:05<00:00, 29.60it/s, accuracy01=0.125, loss=1.388]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train):  99% 165/167 [00:05<00:00, 29.60it/s, accuracy01=0.141, loss=1.374]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (train): 100% 167/167 [00:05<00:00, 28.92it/s, accuracy01=0.125, loss=1.402]
# 1/10 * Epoch (valid):   0% 0/21 [00:00<?, ?it/s]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):   0% 0/21 [00:00<?, ?it/s, accuracy01=0.109, loss=1.375]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):   5% 1/21 [00:00<00:00, 38.68it/s, accuracy01=0.078, loss=1.368]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  10% 2/21 [00:00<00:00, 51.61it/s, accuracy01=0.141, loss=1.397]torch.Size([64, 19, 300])
# torch.Size([64, 1, 19, 300])
# z
# torch.Size([64, 3, 17, 1])
# torch.Size([64, 3, 16, 1])
# torch.Size([64, 3, 15, 1])
# conv2d
# torch.Size([64, 3, 17])
# torch.Size([64, 3, 16])
# torch.Size([64, 3, 15])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  14% 3/21 [00:00<00:00, 57.11it/s, accuracy01=0.141, loss=1.368]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  19% 4/21 [00:00<00:00, 61.32it/s, accuracy01=0.109, loss=1.389]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  24% 5/21 [00:00<00:00, 63.28it/s, accuracy01=0.125, loss=1.391]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  29% 6/21 [00:00<00:00, 66.25it/s, accuracy01=0.094, loss=1.391]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  38% 8/21 [00:00<00:00, 77.14it/s, accuracy01=0.156, loss=1.378]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  38% 8/21 [00:00<00:00, 77.14it/s, accuracy01=0.125, loss=1.413]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  43% 9/21 [00:00<00:00, 77.14it/s, accuracy01=0.109, loss=1.392]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  48% 10/21 [00:00<00:00, 77.14it/s, accuracy01=0.094, loss=1.382]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  52% 11/21 [00:00<00:00, 77.14it/s, accuracy01=0.094, loss=1.369]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  57% 12/21 [00:00<00:00, 77.14it/s, accuracy01=0.141, loss=1.376]torch.Size([64, 17, 300])
# torch.Size([64, 1, 17, 300])
# z
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# conv2d
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  62% 13/21 [00:00<00:00, 77.14it/s, accuracy01=0.062, loss=1.371]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  67% 14/21 [00:00<00:00, 77.14it/s, accuracy01=0.062, loss=1.399]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  71% 15/21 [00:00<00:00, 77.14it/s, accuracy01=0.094, loss=1.408]torch.Size([64, 18, 300])
# torch.Size([64, 1, 18, 300])
# z
# torch.Size([64, 3, 16, 1])
# torch.Size([64, 3, 15, 1])
# torch.Size([64, 3, 14, 1])
# conv2d
# torch.Size([64, 3, 16])
# torch.Size([64, 3, 15])
# torch.Size([64, 3, 14])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  81% 17/21 [00:00<00:00, 78.06it/s, accuracy01=0.125, loss=1.373]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  81% 17/21 [00:00<00:00, 78.06it/s, accuracy01=0.047, loss=1.411]torch.Size([64, 16, 300])
# torch.Size([64, 1, 16, 300])
# z
# torch.Size([64, 3, 14, 1])
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# conv2d
# torch.Size([64, 3, 14])
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  86% 18/21 [00:00<00:00, 78.06it/s, accuracy01=0.203, loss=1.364]torch.Size([64, 15, 300])
# torch.Size([64, 1, 15, 300])
# z
# torch.Size([64, 3, 13, 1])
# torch.Size([64, 3, 12, 1])
# torch.Size([64, 3, 11, 1])
# conv2d
# torch.Size([64, 3, 13])
# torch.Size([64, 3, 12])
# torch.Size([64, 3, 11])
# max pooling
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 3])
# torch.Size([64, 9])
# torch.Size([64, 4])
# 1/10 * Epoch (valid):  90% 19/21 [00:00<00:00, 78.06it/s, accuracy01=0.125, loss=1.370]torch.Size([54, 15, 300])
# torch.Size([54, 1, 15, 300])
# z
# torch.Size([54, 3, 13, 1])
# torch.Size([54, 3, 12, 1])
# torch.Size([54, 3, 11, 1])
# conv2d
# torch.Size([54, 3, 13])
# torch.Size([54, 3, 12])
# torch.Size([54, 3, 11])
# max pooling
# torch.Size([54, 3])
# torch.Size([54, 3])
# torch.Size([54, 3])
# torch.Size([54, 9])
# torch.Size([54, 4])
# 1/10 * Epoch (valid): 100% 21/21 [00:00<00:00, 79.25it/s, accuracy01=0.167, loss=1.373]
# [2020-04-30 22:34:48,849]
# 1/10 * Epoch 1 (_base): lr=0.0100 | momentum=0.000e+00
# 1/10 * Epoch 1 (train): accuracy01=0.1142 | loss=1.3843
# 1/10 * Epoch 1 (valid): accuracy01=0.1143 | loss=1.3836
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/catalyst/core/runner.py in run_experiment(self, experiment)
#     503             for stage in self.experiment.stages:
# --> 504                 self._run_stage(stage)
#     505         except (Exception, KeyboardInterrupt) as ex:
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/catalyst/core/runner.py in _run_stage(self, stage)
#     480             self._run_epoch(stage=stage, epoch=state.epoch)
# --> 481             self._run_event("on_epoch_end")
#     482
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/catalyst/core/runner.py in _run_event(self, event)
#     332         for callback in self.state.callbacks.values():
# --> 333             getattr(callback, event)(self.state)
#     334
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/catalyst/core/callbacks/checkpoint.py in on_epoch_end(self, state)
#     264             main_metric=state.main_metric,
# --> 265             minimize_metric=state.minimize_metric,
#     266         )
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/catalyst/core/callbacks/checkpoint.py in process_checkpoint(self, logdir, checkpoint, is_best, main_metric, minimize_metric)
#     213             is_last=True,
# --> 214             special_suffix="_full",
#     215         )
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/catalyst/utils/checkpoint.py in save_checkpoint(checkpoint, logdir, suffix, is_best, is_last, special_suffix)
#      88     filename = f"{logdir}/{suffix}.pth"
# ---> 89     torch.save(checkpoint, filename)
#      90     if is_best:
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     369     with _open_file_like(f, 'wb') as opened_file:
# --> 370         _legacy_save(obj, opened_file, pickle_module, pickle_protocol)
#     371
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/serialization.py in _legacy_save(obj, f, pickle_module, pickle_protocol)
#     448     for key in serialized_storage_keys:
# --> 449         serialized_storages[key]._write_file(f, _should_read_directly(f), True)
#     450
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-1e89b45fedf0> in <module>
#       9     callbacks=[AccuracyCallback(num_classes=4, accuracy_args=[1])],
#      10     num_epochs=10,
# ---> 11     verbose=True,
#      12 )
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/catalyst/dl/runner/core.py in train(self, model, criterion, optimizer, scheduler, datasets, loaders, callbacks, logdir, resume, num_epochs, valid_loader, main_metric, minimize_metric, verbose, state_kwargs, checkpoint_data, fp16, distributed, check, timeit, load_best_on_end, initial_seed)
#     155         )
#     156         self.experiment = experiment
# --> 157         utils.distributed_cmd_run(self.run_experiment, distributed)
#     158
#     159     def infer(
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/catalyst/utils/scripts.py in distributed_cmd_run(worker_fn, distributed, *args, **kwargs)
#     128         or world_size <= 1
#     129     ):
# --> 130         worker_fn(*args, **kwargs)
#     131     elif local_rank is not None:
#     132         torch.cuda.set_device(int(local_rank))
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/catalyst/core/runner.py in run_experiment(self, experiment)
#     515             ):
#     516                 self.state.exception = ex
# --> 517                 self._run_event("on_exception")
#     518             else:
#     519                 raise ex
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/catalyst/core/runner.py in _run_event(self, event)
#     331         """
#     332         for callback in self.state.callbacks.values():
# --> 333             getattr(callback, event)(self.state)
#     334
#     335     def _batch2device(
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/catalyst/core/callbacks/logging.py in on_exception(self, state)
#      91
#      92         if isinstance(exception, KeyboardInterrupt):
# ---> 93             self.tqdm.write("Early exiting")
#      94             state.need_exception_reraise = False
#      95
#
# AttributeError: 'NoneType' object has no attribute 'write'

# %% [markdown]
# ## 88. パラメータチューニング
# 問題85や問題87のコードを改変し，ニューラルネットワークの形状やハイパーパラメータを調整しながら，高性能なカテゴリ分類器を構築せよ．

# %%
class RNN(nn.Module):
    def __init__(self, num_embeddings,
                 embedding_dim=300,
                 hidden_size=300,
                 output_size=1,
                 num_layers=1,
                 dropout=0.2):
        super().__init__()
        model = KeyedVectors.load_word2vec_format('../ch07/GoogleNews-vectors-negative300.bin', binary=True)
        weights = torch.FloatTensor(model.vectors)
        self.emb = nn.Embedding.from_pretrained(weights)
        self.lstm = nn.LSTM(embedding_dim,
                            hidden_size, num_layers,
                            batch_first=True, dropout=dropout, bidirectional=True)
        self.linear = nn.Sequential(
            nn.Linear(hidden_size * 2, 100),
            nn.PReLU(),
            nn.BatchNorm1d(100),
            nn.Linear(100, output_size)
        )

    def forward(self, x, h0=None):
        x = self.emb(x)
        x, h = self.lstm(x, h0)
        x = x[:, -1, :]
        x = self.linear(x)
        return x

# %% [markdown]
# ## 89. 事前学習済み言語モデルからの転移学習
# 事前学習済み言語モデル（例えばBERTなど）を出発点として，ニュース記事見出しをカテゴリに分類するモデルを構築せよ．

# %%
# %%bash
# # pip install transformers

# %%
from tqdm import tqdm
from transformers import BertForSequenceClassification

# %%
def eval_net(model, data_loader, device='cpu'):
    model.eval()
    ys = []
    ypreds = []
    for x, y, _ in data_loader:
        with torch.no_grad():
            loss, logit = model(input_ids=x, labels=y)
            _, y_pred = torch.max(logit, 1)
            ys.append(y)
            ypreds.append(y_pred)
    ys = torch.cat(ys)
    ypreds = torch.cat(ypreds)
    print(f'test acc: {(ys == ypreds).sum().item() / len(ys)}')
    return

# %%
TEXT = data.Field(sequential=True, lower=True, batch_first=True)
LABELS = data.Field(sequential=False, batch_first=True, use_vocab=False)

train, val, test = data.TabularDataset.splits(
    path='../ch06', train='train.txt',
    validation='valid.txt', test='test.txt', format='tsv',
    fields=[('TEXT', TEXT), ('LABEL', LABELS)])

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
train_iter, val_iter, test_iter = data.Iterator.splits(
    (train, val, test), batch_sizes=(64, 64, 64), device=device, repeat=False, sort=False)

TEXT.build_vocab(train, min_freq=2)
LABELS.build_vocab(train)

model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=4)
model = model.to(device)

optimizer = optim.SGD(model.parameters(), lr=0.01)

for epoch in tqdm(range(10)):
    losses = []
    model.train()
    for batch in train_iter:
        x, y = batch.TEXT, batch.LABEL
        loss, logit = model(input_ids=x, labels=y)
        model.zero_grad()
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
        _, y_pred_train = torch.max(logit, 1)
    eval_net(model, test_iter, device)
# Out:
#   0%|          | 0/10 [00:36<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-c8677a02cd24> in <module>
#      24     for batch in train_iter:
#      25         x, y = batch.TEXT, batch.LABEL
# ---> 26         loss, logit = model(input_ids=x, labels=y)
#      27         model.zero_grad()
#      28         loss.backward()
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/transformers/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels)
#    1174             position_ids=position_ids,
#    1175             head_mask=head_mask,
# -> 1176             inputs_embeds=inputs_embeds,
#    1177         )
#    1178
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/transformers/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask)
#     788             head_mask=head_mask,
#     789             encoder_hidden_states=encoder_hidden_states,
# --> 790             encoder_attention_mask=encoder_extended_attention_mask,
#     791         )
#     792         sequence_output = encoder_outputs[0]
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask)
#     405
#     406             layer_outputs = layer_module(
# --> 407                 hidden_states, attention_mask, head_mask[i], encoder_hidden_states, encoder_attention_mask
#     408             )
#     409             hidden_states = layer_outputs[0]
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask)
#     366         encoder_attention_mask=None,
#     367     ):
# --> 368         self_attention_outputs = self.attention(hidden_states, attention_mask, head_mask)
#     369         attention_output = self_attention_outputs[0]
#     370         outputs = self_attention_outputs[1:]  # add self attentions if we output attention weights
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask)
#     312     ):
#     313         self_outputs = self.self(
# --> 314             hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask
#     315         )
#     316         attention_output = self.output(self_outputs[0], hidden_states)
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask)
#     239
#     240         # Normalize the attention scores to probabilities.
# --> 241         attention_probs = nn.Softmax(dim=-1)(attention_scores)
#     242
#     243         # This is actually dropping out entire tokens to attend to, which might
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/modules/activation.py in forward(self, input)
#    1042
#    1043     def forward(self, input):
# -> 1044         return F.softmax(input, self.dim, _stacklevel=5)
#    1045
#    1046     def extra_repr(self):
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/functional.py in softmax(input, dim, _stacklevel, dtype)
#    1440         dim = _get_softmax_dim('softmax', input.dim(), _stacklevel)
#    1441     if dtype is None:
# -> 1442         ret = input.softmax(dim)
#    1443     else:
#    1444         ret = input.softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:
